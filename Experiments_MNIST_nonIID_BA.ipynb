# %%
#================================= Start of importing required packages and libraries =========================================#
from __future__ import print_function
# %matplotlib inline
import numpy as np
import torch
from experiment_federated import *
import random
#================================== End of importing required packages and libraries ==========================================#

# %%
#=============================== Defining global variables ========================#
DATASET_NAME = "MNIST"
MODEL_NAME = "CNNMNIST"
DD_TYPE = 'MILD_NON_IID'
ALPHA = 1
NUM_PEERS = 20 # "number of peers: K" 
FRAC_PEERS = 1 #'the fraction of peers: C to bel selected in each round'
SEED = 7 #fixed seed
random.seed(SEED)
CRITERION = nn.CrossEntropyLoss()
GLOBAL_ROUNDS = 30 #"number of rounds of federated model training"
LOCAL_EPOCHS = 1 #"the number of local epochs: E for each peer"
TEST_BATCH_SIZE = 1000
LOCAL_BS = 64 #"local batch size: B for each peer"
LOCAL_LR =  0.01#local learning rate: lr for each peer
LOCAL_MOMENTUM = 0.9 #local momentum for each peer
NUM_CLASSES = 10 # number of classes in an experiment
LABELS_DICT = {'Zero':0,
               'One':1, 
               'Two':2, 
               'Three':3, 
               'Four':4,
               'Five':5, 
               'Six':6, 
               'Seven':7, 
               'Eight':8, 
               'Nine':9}

#select the device to work with cpu or gpu
if torch.cuda.is_available():
    DEVICE = "cuda"
else:
    DEVICE = "cpu"
DEVICE = torch.device(DEVICE)
SOURCE_CLASS = 2 # the source class
TARGET_CLASS = 5 # the target class 

CLASS_PER_PEER = 10
SAMPLES_PER_CLASS = 582
RATE_UNBALANCE = 1

# %%
# Baseline|: FedAvg-no attacks (FL)
RULE = 'fedavg'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.9, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: fedavg
# Attack Type: backdoor
# Attackers Ratio: 90.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.912423
#
# Average test loss: 1.9535, Test accuracy: 2850/10000 (28.50%)
#
# Class      - Accuracy
# Zero       - 0.0
# One        - 80.1
# Two        - 0.4
# Three      - 8.8
# Four       - 43.4
# Five       - 99.0
# Six        - 0.1
# Seven      - 49.6
# Eight      - 0.0
# Nine       - 2.8
#
# Backdoor ASR 99.52
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.281277
#
# Average test loss: 0.7641, Test accuracy: 8119/10000 (81.19%)
#
# Class      - Accuracy
# Zero       - 96.1
# One        - 98.4
# Two        - 60.5
# Three      - 82.2
# Four       - 91.9
# Five       - 74.8
# Six        - 91.3
# Seven      - 80.0
# Eight      - 55.5
# Nine       - 79.2
#
# Backdoor ASR 30.33
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.855009
#
# Average test loss: 0.4780, Test accuracy: 8941/10000 (89.41%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.5
# Two        - 85.3
# Three      - 89.7
# Four       - 95.4
# Five       - 82.7
# Six        - 95.9
# Seven      - 84.3
# Eight      - 77.0
# Nine       - 85.8
#
# Backdoor ASR 7.36
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.717022
#
# Average test loss: 0.3781, Test accuracy: 9176/10000 (91.76%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 98.7
# Two        - 88.1
# Three      - 90.7
# Four       - 96.1
# Five       - 89.0
# Six        - 96.8
# Seven      - 87.2
# Eight      - 83.0
# Nine       - 89.8
#
# Backdoor ASR 5.04
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.624258
#
# Average test loss: 0.3136, Test accuracy: 9292/10000 (92.92%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.7
# Two        - 89.0
# Three      - 92.1
# Four       - 96.0
# Five       - 93.2
# Six        - 97.2
# Seven      - 87.5
# Eight      - 85.5
# Nine       - 91.4
#
# Backdoor ASR 5.14
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.572519
#
# Average test loss: 0.2730, Test accuracy: 9395/10000 (93.95%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.8
# Two        - 92.3
# Three      - 93.2
# Four       - 95.9
# Five       - 92.6
# Six        - 97.6
# Seven      - 88.7
# Eight      - 89.0
# Nine       - 92.8
#
# Backdoor ASR 2.42
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.529917
#
# Average test loss: 0.2507, Test accuracy: 9454/10000 (94.54%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 92.4
# Three      - 93.3
# Four       - 96.4
# Five       - 95.7
# Six        - 97.4
# Seven      - 90.4
# Eight      - 89.2
# Nine       - 93.2
#
# Backdoor ASR 3.1
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.503958
#
# Average test loss: 0.2244, Test accuracy: 9505/10000 (95.05%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 94.5
# Three      - 94.5
# Four       - 97.0
# Five       - 95.0
# Six        - 97.8
# Seven      - 90.3
# Eight      - 90.6
# Nine       - 93.3
#
# Backdoor ASR 1.45
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.484349
#
# Average test loss: 0.2185, Test accuracy: 9532/10000 (95.32%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 93.7
# Three      - 94.5
# Four       - 96.6
# Five       - 96.3
# Six        - 97.7
# Seven      - 91.2
# Eight      - 91.6
# Nine       - 94.0
#
# Backdoor ASR 2.33
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.463764
#
# Average test loss: 0.2046, Test accuracy: 9543/10000 (95.43%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 94.5
# Three      - 94.4
# Four       - 97.0
# Five       - 96.2
# Six        - 97.9
# Seven      - 90.9
# Eight      - 91.6
# Nine       - 94.4
#
# Backdoor ASR 1.45
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.445339
#
# Average test loss: 0.1914, Test accuracy: 9573/10000 (95.73%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 94.5
# Three      - 95.8
# Four       - 97.3
# Five       - 95.9
# Six        - 98.1
# Seven      - 92.1
# Eight      - 91.9
# Nine       - 94.2
#
# Backdoor ASR 1.16
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.435814
#
# Average test loss: 0.1807, Test accuracy: 9596/10000 (95.96%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 95.7
# Three      - 96.1
# Four       - 96.8
# Five       - 96.1
# Six        - 98.0
# Seven      - 91.7
# Eight      - 92.5
# Nine       - 94.8
#
# Backdoor ASR 0.68
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.420521
#
# Average test loss: 0.1725, Test accuracy: 9628/10000 (96.28%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 95.7
# Three      - 96.1
# Four       - 97.1
# Five       - 96.7
# Six        - 98.0
# Seven      - 93.0
# Eight      - 93.4
# Nine       - 94.6
#
# Backdoor ASR 0.87
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.414487
#
# Average test loss: 0.1689, Test accuracy: 9629/10000 (96.29%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 95.6
# Three      - 96.3
# Four       - 96.7
# Five       - 97.0
# Six        - 98.3
# Seven      - 92.6
# Eight      - 93.5
# Nine       - 95.1
#
# Backdoor ASR 0.87
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.401509
#
# Average test loss: 0.1664, Test accuracy: 9646/10000 (96.46%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 96.3
# Three      - 96.4
# Four       - 97.1
# Five       - 97.4
# Six        - 98.2
# Seven      - 92.5
# Eight      - 93.5
# Nine       - 95.1
#
# Backdoor ASR 0.78
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.390631
#
# Average test loss: 0.1577, Test accuracy: 9676/10000 (96.76%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 96.5
# Three      - 96.7
# Four       - 97.5
# Five       - 97.5
# Six        - 98.2
# Seven      - 93.9
# Eight      - 94.1
# Nine       - 94.9
#
# Backdoor ASR 0.97
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.381993
#
# Average test loss: 0.1531, Test accuracy: 9686/10000 (96.86%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 96.4
# Three      - 96.8
# Four       - 97.1
# Five       - 97.9
# Six        - 98.2
# Seven      - 93.5
# Eight      - 95.0
# Nine       - 95.3
#
# Backdoor ASR 0.68
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.372446
#
# Average test loss: 0.1479, Test accuracy: 9684/10000 (96.84%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.0
# Two        - 96.5
# Three      - 96.8
# Four       - 97.7
# Five       - 98.2
# Six        - 98.3
# Seven      - 93.0
# Eight      - 94.1
# Nine       - 95.6
#
# Backdoor ASR 0.87
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.376849
#
# Average test loss: 0.1483, Test accuracy: 9695/10000 (96.95%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 96.7
# Three      - 96.7
# Four       - 97.6
# Five       - 97.9
# Six        - 98.5
# Seven      - 93.9
# Eight      - 94.7
# Nine       - 95.3
#
# Backdoor ASR 0.78
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.363788
#
# Average test loss: 0.1442, Test accuracy: 9704/10000 (97.04%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 96.4
# Three      - 96.9
# Four       - 97.1
# Five       - 98.3
# Six        - 98.1
# Seven      - 94.2
# Eight      - 95.4
# Nine       - 95.8
#
# Backdoor ASR 0.97
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.357884
#
# Average test loss: 0.1428, Test accuracy: 9714/10000 (97.14%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 96.8
# Three      - 97.1
# Four       - 97.3
# Five       - 98.3
# Six        - 98.4
# Seven      - 94.4
# Eight      - 94.9
# Nine       - 96.0
#
# Backdoor ASR 0.87
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.354538
#
# Average test loss: 0.1332, Test accuracy: 9720/10000 (97.20%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.1
# Two        - 97.3
# Three      - 96.8
# Four       - 97.5
# Five       - 98.4
# Six        - 98.5
# Seven      - 94.5
# Eight      - 94.8
# Nine       - 95.8
#
# Backdoor ASR 0.58
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.347439
#
# Average test loss: 0.1333, Test accuracy: 9742/10000 (97.42%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.2
# Two        - 97.2
# Three      - 97.2
# Four       - 97.9
# Five       - 98.2
# Six        - 98.5
# Seven      - 95.1
# Eight      - 95.5
# Nine       - 96.1
# Backdoor ASR 0.39
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.341924
#
# Average test loss: 0.1305, Test accuracy: 9746/10000 (97.46%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.2
# Two        - 97.2
# Three      - 97.1
# Four       - 97.8
# Five       - 98.5
# Six        - 98.4
# Seven      - 95.3
# Eight      - 95.6
# Nine       - 96.1
#
# Backdoor ASR 0.68
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.336598
#
# Average test loss: 0.1280, Test accuracy: 9742/10000 (97.42%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 97.4
# Three      - 96.9
# Four       - 97.7
# Five       - 98.4
# Six        - 98.6
# Seven      - 94.9
# Eight      - 95.6
# Nine       - 96.0
#
# Backdoor ASR 0.58
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.332726
#
# Average test loss: 0.1335, Test accuracy: 9737/10000 (97.37%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.2
# Two        - 96.7
# Three      - 97.3
# Four       - 97.7
# Five       - 98.4
# Six        - 98.4
# Seven      - 94.9
# Eight      - 95.6
# Nine       - 96.1
#
# Backdoor ASR 0.97
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.331196
#
# Average test loss: 0.1199, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 97.3
# Three      - 97.7
# Four       - 97.8
# Five       - 98.3
# Six        - 98.5
# Seven      - 95.0
# Eight      - 96.4
# Nine       - 96.1
#
# Backdoor ASR 0.58
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.326424
#
# Average test loss: 0.1249, Test accuracy: 9766/10000 (97.66%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 97.0
# Three      - 97.8
# Four       - 97.9
# Five       - 98.3
# Six        - 98.9
# Seven      - 95.3
# Eight      - 96.5
# Nine       - 96.2
#
# Backdoor ASR 0.78
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.327364
#
# Average test loss: 0.1232, Test accuracy: 9765/10000 (97.65%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 97.7
# Three      - 97.7
# Four       - 97.9
# Five       - 98.4
# Six        - 98.6
# Seven      - 94.6
# Eight      - 96.8
# Nine       - 96.0
#
# Backdoor ASR 0.39
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.322530
#
# Average test loss: 0.1169, Test accuracy: 9776/10000 (97.76%)
#
# Class      - Accuracy
# Zero       - 99.4
# One        - 99.4
# Two        - 97.8
# Three      - 97.9
# Four       - 98.1
# Five       - 98.4
# Six        - 98.7
# Seven      - 95.0
# Eight      - 96.8
# Nine       - 96.0
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.1278, Test accuracy: 9742/10000 (97.42%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 97.1
# Three      - 97.3
# Four       - 97.8
# Five       - 98.4
# Six        - 98.6
# Seven      - 94.7
# Eight      - 95.6
# Nine       - 96.0
# Global accuracies:  [28.5, 81.19, 89.41, 91.76, 92.92, 93.95, 94.54, 95.05, 95.32, 95.43, 95.73, 95.96, 96.28, 96.29, 96.46, 96.76, 96.86, 96.84, 96.95, 97.04, 97.14, 97.2, 97.42, 97.46, 97.42, 97.37, 97.6, 97.66, 97.65, 97.76, 97.42]
# Class 2 accuracies:  [0.39, 60.47, 85.27, 88.08, 88.95, 92.34, 92.44, 94.48, 93.7, 94.48, 94.48, 95.74, 95.74, 95.64, 96.32, 96.51, 96.41, 96.51, 96.71, 96.41, 96.8, 97.29, 97.19, 97.19, 97.38, 96.71, 97.29, 97.0, 97.67, 97.77, 97.09]
# Test loss: [1.9535, 0.7641, 0.478, 0.3781, 0.3136, 0.273, 0.2507, 0.2244, 0.2185, 0.2046, 0.1914, 0.1807, 0.1725, 0.1689, 0.1664, 0.1577, 0.1531, 0.1479, 0.1483, 0.1442, 0.1428, 0.1332, 0.1333, 0.1305, 0.128, 0.1335, 0.1199, 0.1249, 0.1232, 0.1169, 0.1278]
# Label-flipping attack succes rate: 0.58
# Backdoor attack succes rate: 0.68
# Average CPU aggregation runtime: 0.0023608764012654623
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: fedavg
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.892243
#
# Average test loss: 1.8816, Test accuracy: 6912/10000 (69.12%)
#
# Class      - Accuracy
# Zero       - 67.1
# One        - 94.4
# Two        - 91.2
# Three      - 87.6
# Four       - 85.5
# Five       - 40.1
# Six        - 72.7
# Seven      - 64.7
# Eight      - 32.4
# Nine       - 47.7
#
# Backdoor ASR 0.48
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.194180
#
# Average test loss: 0.6142, Test accuracy: 8572/10000 (85.72%)
#
# Class      - Accuracy
# Zero       - 96.1
# One        - 98.3
# Two        - 89.1
# Three      - 86.2
# Four       - 91.6
# Five       - 78.0
# Six        - 92.2
# Seven      - 79.7
# Eight      - 63.9
# Nine       - 79.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.737512
#
# Average test loss: 0.3774, Test accuracy: 9096/10000 (90.96%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.5
# Two        - 92.6
# Three      - 90.8
# Four       - 94.9
# Five       - 87.1
# Six        - 96.0
# Seven      - 86.3
# Eight      - 76.5
# Nine       - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.585157
#
# Average test loss: 0.2823, Test accuracy: 9263/10000 (92.63%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.7
# Two        - 93.0
# Three      - 92.7
# Four       - 97.0
# Five       - 90.5
# Six        - 96.8
# Seven      - 87.5
# Eight      - 82.8
# Nine       - 88.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.504069
#
# Average test loss: 0.2295, Test accuracy: 9375/10000 (93.75%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.7
# Two        - 93.6
# Three      - 93.6
# Four       - 95.9
# Five       - 93.4
# Six        - 96.9
# Seven      - 88.4
# Eight      - 85.6
# Nine       - 92.8
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.450499
#
# Average test loss: 0.2021, Test accuracy: 9441/10000 (94.41%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.8
# Two        - 94.7
# Three      - 93.7
# Four       - 96.8
# Five       - 95.3
# Six        - 97.0
# Seven      - 88.1
# Eight      - 87.9
# Nine       - 93.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.418616
#
# Average test loss: 0.1760, Test accuracy: 9502/10000 (95.02%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 95.0
# Three      - 94.5
# Four       - 96.2
# Five       - 96.0
# Six        - 97.3
# Seven      - 90.3
# Eight      - 89.9
# Nine       - 93.6
#
# Backdoor ASR 0.19
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.387472
#
# Average test loss: 0.1626, Test accuracy: 9533/10000 (95.33%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 95.1
# Three      - 95.0
# Four       - 96.3
# Five       - 96.3
# Six        - 97.6
# Seven      - 91.0
# Eight      - 89.7
# Nine       - 94.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.367263
#
# Average test loss: 0.1503, Test accuracy: 9559/10000 (95.59%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.0
# Three      - 95.4
# Four       - 97.0
# Five       - 97.0
# Six        - 97.7
# Seven      - 90.5
# Eight      - 90.2
# Nine       - 94.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.345531
#
# Average test loss: 0.1390, Test accuracy: 9584/10000 (95.84%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 95.6
# Three      - 95.3
# Four       - 97.1
# Five       - 97.3
# Six        - 97.5
# Seven      - 91.5
# Eight      - 91.3
# Nine       - 94.8
#
# Backdoor ASR 0.1
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.331408
#
# Average test loss: 0.1303, Test accuracy: 9612/10000 (96.12%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.2
# Three      - 96.0
# Four       - 97.1
# Five       - 97.3
# Six        - 97.7
# Seven      - 91.9
# Eight      - 92.1
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.315911
#
# Average test loss: 0.1231, Test accuracy: 9619/10000 (96.19%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 96.3
# Three      - 95.2
# Four       - 97.1
# Five       - 97.9
# Six        - 97.4
# Seven      - 91.6
# Eight      - 93.1
# Nine       - 95.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.312572
#
# Average test loss: 0.1195, Test accuracy: 9646/10000 (96.46%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.5
# Three      - 96.3
# Four       - 97.1
# Five       - 97.9
# Six        - 98.1
# Seven      - 92.1
# Eight      - 92.4
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.297476
#
# Average test loss: 0.1111, Test accuracy: 9672/10000 (96.72%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 97.5
# Three      - 95.8
# Four       - 97.4
# Five       - 98.0
# Six        - 98.0
# Seven      - 93.1
# Eight      - 93.7
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.292459
#
# Average test loss: 0.1068, Test accuracy: 9681/10000 (96.81%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 97.3
# Three      - 96.5
# Four       - 97.5
# Five       - 98.3
# Six        - 98.0
# Seven      - 92.8
# Eight      - 94.0
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.278424
#
# Average test loss: 0.1024, Test accuracy: 9702/10000 (97.02%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 97.7
# Three      - 96.7
# Four       - 97.3
# Five       - 98.3
# Six        - 97.6
# Seven      - 94.0
# Eight      - 94.6
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.266842
#
# Average test loss: 0.0974, Test accuracy: 9712/10000 (97.12%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 97.6
# Three      - 96.8
# Four       - 97.5
# Five       - 98.4
# Six        - 98.0
# Seven      - 94.2
# Eight      - 94.9
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.271602
#
# Average test loss: 0.0943, Test accuracy: 9713/10000 (97.13%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 97.5
# Three      - 97.0
# Four       - 97.3
# Five       - 98.3
# Six        - 98.2
# Seven      - 94.5
# Eight      - 94.7
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.258380
#
# Average test loss: 0.0925, Test accuracy: 9718/10000 (97.18%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 97.7
# Three      - 97.2
# Four       - 97.4
# Five       - 98.5
# Six        - 98.1
# Seven      - 94.1
# Eight      - 94.6
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.255703
#
# Average test loss: 0.0914, Test accuracy: 9724/10000 (97.24%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.8
# Three      - 97.3
# Four       - 97.3
# Five       - 98.4
# Six        - 98.1
# Seven      - 94.6
# Eight      - 94.4
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.253551
#
# Average test loss: 0.0876, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.8
# Three      - 97.0
# Four       - 97.3
# Five       - 98.7
# Six        - 98.4
# Seven      - 95.2
# Eight      - 95.3
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.247114
#
# Average test loss: 0.0857, Test accuracy: 9735/10000 (97.35%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.4
# Three      - 97.0
# Four       - 97.3
# Five       - 98.8
# Six        - 98.1
# Seven      - 94.7
# Eight      - 95.4
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.242565
#
# Average test loss: 0.0840, Test accuracy: 9749/10000 (97.49%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 98.1
# Three      - 96.9
# Four       - 98.1
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.0
# Eight      - 95.5
# Nine       - 96.0
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.237575
#
# Average test loss: 0.0802, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.6
# Three      - 97.5
# Four       - 97.9
# Five       - 98.8
# Six        - 98.2
# Seven      - 95.1
# Eight      - 96.2
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.229371
#
# Average test loss: 0.0799, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 98.0
# Three      - 97.2
# Four       - 97.6
# Five       - 98.8
# Six        - 98.6
# Seven      - 95.1
# Eight      - 96.3
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.227537
#
# Average test loss: 0.0793, Test accuracy: 9749/10000 (97.49%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 98.1
# Three      - 97.3
# Four       - 97.8
# Five       - 98.9
# Six        - 97.9
# Seven      - 95.0
# Eight      - 95.4
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.226032
#
# Average test loss: 0.0767, Test accuracy: 9764/10000 (97.64%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 98.2
# Three      - 97.2
# Four       - 97.9
# Five       - 98.7
# Six        - 98.3
# Seven      - 95.6
# Eight      - 95.8
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.221582
#
# Average test loss: 0.0754, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 98.1
# Three      - 97.4
# Four       - 98.4
# Five       - 98.8
# Six        - 98.6
# Seven      - 95.7
# Eight      - 96.1
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.222315
#
# Average test loss: 0.0733, Test accuracy: 9781/10000 (97.81%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.8
# Three      - 97.5
# Four       - 98.0
# Five       - 99.0
# Six        - 98.5
# Seven      - 95.0
# Eight      - 96.1
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.218533
#
# Average test loss: 0.0708, Test accuracy: 9784/10000 (97.84%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.7
# Three      - 97.5
# Four       - 98.1
# Five       - 98.9
# Six        - 98.5
# Seven      - 95.6
# Eight      - 96.1
# Nine       - 96.5
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0785, Test accuracy: 9762/10000 (97.62%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 98.2
# Three      - 97.3
# Four       - 97.7
# Five       - 98.9
# Six        - 98.3
# Seven      - 95.2
# Eight      - 96.0
# Nine       - 96.3
# Global accuracies:  [69.12, 85.72, 90.96, 92.63, 93.75, 94.41, 95.02, 95.33, 95.59, 95.84, 96.12, 96.19, 96.46, 96.72, 96.81, 97.02, 97.12, 97.13, 97.18, 97.24, 97.43, 97.35, 97.49, 97.56, 97.6, 97.49, 97.64, 97.78, 97.81, 97.84, 97.62]
# Class 2 accuracies:  [91.18, 89.15, 92.64, 93.02, 93.6, 94.67, 94.96, 95.06, 96.03, 95.64, 96.22, 96.32, 97.48, 97.48, 97.29, 97.67, 97.58, 97.48, 97.67, 97.77, 97.77, 97.38, 98.06, 97.58, 97.97, 98.06, 98.16, 98.06, 98.84, 98.74, 98.16]
# Test loss: [1.8816, 0.6142, 0.3774, 0.2823, 0.2295, 0.2021, 0.176, 0.1626, 0.1503, 0.139, 0.1303, 0.1231, 0.1195, 0.1111, 0.1068, 0.1024, 0.0974, 0.0943, 0.0925, 0.0914, 0.0876, 0.0857, 0.084, 0.0802, 0.0799, 0.0793, 0.0767, 0.0754, 0.0733, 0.0708, 0.0785]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.002276817957560221
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: fedavg
# Attack Type: backdoor
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.893780
#
# Average test loss: 1.8883, Test accuracy: 6786/10000 (67.86%)
#
# Class      - Accuracy
# Zero       - 55.1
# One        - 93.8
# Two        - 89.7
# Three      - 84.3
# Four       - 87.9
# Five       - 64.5
# Six        - 68.4
# Seven      - 65.1
# Eight      - 23.1
# Nine       - 41.3
#
# Backdoor ASR 2.52
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.215606
#
# Average test loss: 0.6539, Test accuracy: 8512/10000 (85.12%)
#
# Class      - Accuracy
# Zero       - 96.4
# One        - 98.5
# Two        - 88.2
# Three      - 84.9
# Four       - 90.0
# Five       - 76.1
# Six        - 91.8
# Seven      - 79.9
# Eight      - 60.0
# Nine       - 82.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.766393
#
# Average test loss: 0.3863, Test accuracy: 9102/10000 (91.02%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.5
# Two        - 92.2
# Three      - 90.4
# Four       - 94.1
# Five       - 88.8
# Six        - 95.7
# Seven      - 85.4
# Eight      - 77.1
# Nine       - 88.6
#
# Backdoor ASR 0.19
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.618078
#
# Average test loss: 0.2863, Test accuracy: 9257/10000 (92.57%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 91.8
# Three      - 91.5
# Four       - 96.7
# Five       - 91.8
# Six        - 96.2
# Seven      - 87.3
# Eight      - 82.6
# Nine       - 90.0
#
# Backdoor ASR 0.19
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.531751
#
# Average test loss: 0.2404, Test accuracy: 9362/10000 (93.62%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 93.3
# Three      - 93.0
# Four       - 96.3
# Five       - 94.1
# Six        - 97.3
# Seven      - 88.1
# Eight      - 84.9
# Nine       - 91.7
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.494293
#
# Average test loss: 0.2097, Test accuracy: 9431/10000 (94.31%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 93.8
# Three      - 93.8
# Four       - 96.5
# Five       - 94.6
# Six        - 97.2
# Seven      - 88.1
# Eight      - 88.2
# Nine       - 93.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.449999
#
# Average test loss: 0.1808, Test accuracy: 9493/10000 (94.93%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.7
# Two        - 94.1
# Three      - 94.1
# Four       - 97.1
# Five       - 95.9
# Six        - 97.8
# Seven      - 89.3
# Eight      - 90.6
# Nine       - 93.3
#
# Backdoor ASR 0.19
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.427632
#
# Average test loss: 0.1686, Test accuracy: 9528/10000 (95.28%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 94.5
# Three      - 94.8
# Four       - 96.9
# Five       - 96.6
# Six        - 97.3
# Seven      - 90.4
# Eight      - 91.0
# Nine       - 93.8
#
# Backdoor ASR 0.19
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.403125
#
# Average test loss: 0.1551, Test accuracy: 9563/10000 (95.63%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.8
# Two        - 95.6
# Three      - 94.8
# Four       - 97.0
# Five       - 96.6
# Six        - 97.7
# Seven      - 90.8
# Eight      - 91.6
# Nine       - 94.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.385649
#
# Average test loss: 0.1442, Test accuracy: 9584/10000 (95.84%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 96.0
# Three      - 95.8
# Four       - 97.1
# Five       - 97.4
# Six        - 97.8
# Seven      - 90.6
# Eight      - 91.3
# Nine       - 95.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.367763
#
# Average test loss: 0.1335, Test accuracy: 9617/10000 (96.17%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 96.5
# Three      - 95.6
# Four       - 97.1
# Five       - 97.1
# Six        - 97.9
# Seven      - 91.9
# Eight      - 92.9
# Nine       - 94.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.358191
#
# Average test loss: 0.1258, Test accuracy: 9633/10000 (96.33%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.7
# Three      - 95.4
# Four       - 97.0
# Five       - 98.3
# Six        - 97.7
# Seven      - 92.4
# Eight      - 92.8
# Nine       - 95.1
#
# Backdoor ASR 0.1
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.340261
#
# Average test loss: 0.1185, Test accuracy: 9645/10000 (96.45%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 97.2
# Three      - 96.2
# Four       - 97.1
# Five       - 97.8
# Six        - 97.8
# Seven      - 92.2
# Eight      - 93.0
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.331232
#
# Average test loss: 0.1140, Test accuracy: 9674/10000 (96.74%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 96.7
# Three      - 96.2
# Four       - 97.3
# Five       - 98.7
# Six        - 97.9
# Seven      - 93.6
# Eight      - 93.8
# Nine       - 95.2
#
# Backdoor ASR 0.1
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.324827
#
# Average test loss: 0.1106, Test accuracy: 9674/10000 (96.74%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 97.1
# Three      - 96.5
# Four       - 97.3
# Five       - 98.3
# Six        - 98.2
# Seven      - 92.8
# Eight      - 94.4
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.311638
#
# Average test loss: 0.1037, Test accuracy: 9687/10000 (96.87%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.2
# Three      - 96.4
# Four       - 97.3
# Five       - 98.4
# Six        - 97.8
# Seven      - 93.4
# Eight      - 95.0
# Nine       - 95.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.313640
#
# Average test loss: 0.1036, Test accuracy: 9695/10000 (96.95%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.2
# Three      - 96.9
# Four       - 97.3
# Five       - 98.7
# Six        - 98.1
# Seven      - 93.5
# Eight      - 94.3
# Nine       - 95.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.298897
#
# Average test loss: 0.0971, Test accuracy: 9712/10000 (97.12%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 97.6
# Three      - 97.2
# Four       - 97.7
# Five       - 98.4
# Six        - 97.9
# Seven      - 94.0
# Eight      - 94.7
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.294231
#
# Average test loss: 0.0937, Test accuracy: 9726/10000 (97.26%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.7
# Three      - 97.0
# Four       - 97.5
# Five       - 98.7
# Six        - 97.9
# Seven      - 94.6
# Eight      - 95.0
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.285103
#
# Average test loss: 0.0920, Test accuracy: 9738/10000 (97.38%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 97.7
# Three      - 97.1
# Four       - 97.6
# Five       - 98.4
# Six        - 98.4
# Seven      - 94.7
# Eight      - 95.4
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.286398
#
# Average test loss: 0.0905, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.8
# Three      - 97.2
# Four       - 97.8
# Five       - 98.5
# Six        - 98.4
# Seven      - 94.5
# Eight      - 95.7
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.279984
#
# Average test loss: 0.0873, Test accuracy: 9737/10000 (97.37%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.8
# Three      - 97.5
# Four       - 97.0
# Five       - 98.8
# Six        - 98.0
# Seven      - 94.3
# Eight      - 95.6
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.274063
#
# Average test loss: 0.0853, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.7
# Three      - 97.7
# Four       - 98.1
# Five       - 98.4
# Six        - 98.3
# Seven      - 94.9
# Eight      - 95.7
# Nine       - 96.1
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.269475
#
# Average test loss: 0.0837, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.9
# Three      - 97.2
# Four       - 97.6
# Five       - 98.8
# Six        - 98.3
# Seven      - 95.1
# Eight      - 96.0
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.263545
#
# Average test loss: 0.0812, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.5
# Two        - 97.7
# Three      - 97.6
# Four       - 97.7
# Five       - 98.8
# Six        - 98.2
# Seven      - 95.5
# Eight      - 95.6
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.259084
#
# Average test loss: 0.0796, Test accuracy: 9761/10000 (97.61%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 98.1
# Three      - 97.3
# Four       - 98.0
# Five       - 99.0
# Six        - 98.3
# Seven      - 95.3
# Eight      - 95.7
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.259088
#
# Average test loss: 0.0782, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.8
# Three      - 97.4
# Four       - 97.8
# Five       - 98.9
# Six        - 98.2
# Seven      - 95.7
# Eight      - 96.2
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.253230
#
# Average test loss: 0.0774, Test accuracy: 9766/10000 (97.66%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 97.8
# Three      - 97.5
# Four       - 97.9
# Five       - 98.9
# Six        - 98.6
# Seven      - 95.5
# Eight      - 95.9
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.250664
#
# Average test loss: 0.0767, Test accuracy: 9772/10000 (97.72%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 98.1
# Three      - 97.6
# Four       - 97.9
# Five       - 98.9
# Six        - 98.4
# Seven      - 95.1
# Eight      - 96.2
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.245043
#
# Average test loss: 0.0746, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 98.2
# Three      - 97.5
# Four       - 98.1
# Five       - 98.9
# Six        - 98.4
# Seven      - 95.6
# Eight      - 96.1
# Nine       - 96.7
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0808, Test accuracy: 9762/10000 (97.62%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.0
# Three      - 97.4
# Four       - 97.9
# Five       - 98.8
# Six        - 98.3
# Seven      - 95.4
# Eight      - 96.0
# Nine       - 96.2
# Global accuracies:  [67.86, 85.12, 91.02, 92.57, 93.62, 94.31, 94.93, 95.28, 95.63, 95.84, 96.17, 96.33, 96.45, 96.74, 96.74, 96.87, 96.95, 97.12, 97.26, 97.38, 97.43, 97.37, 97.53, 97.56, 97.6, 97.61, 97.67, 97.66, 97.72, 97.78, 97.62]
# Class 2 accuracies:  [89.73, 88.18, 92.15, 91.76, 93.31, 93.8, 94.09, 94.48, 95.64, 96.03, 96.51, 96.71, 97.19, 96.71, 97.09, 97.19, 97.19, 97.58, 97.67, 97.67, 97.77, 97.77, 97.67, 97.87, 97.67, 98.06, 97.77, 97.77, 98.06, 98.16, 97.97]
# Test loss: [1.8883, 0.6539, 0.3863, 0.2863, 0.2404, 0.2097, 0.1808, 0.1686, 0.1551, 0.1442, 0.1335, 0.1258, 0.1185, 0.114, 0.1106, 0.1037, 0.1036, 0.0971, 0.0937, 0.092, 0.0905, 0.0873, 0.0853, 0.0837, 0.0812, 0.0796, 0.0782, 0.0774, 0.0767, 0.0746, 0.0808]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.002196820576985677
#
# --> End of Experiment.

# %%
RULE = 'median'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: median
# Attack Type: backdoor
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.885248
#
# Average test loss: 2.0245, Test accuracy: 5300/10000 (53.00%)
#
# Class      - Accuracy
# Zero       - 32.1
# One        - 84.7
# Two        - 98.7
# Three      - 70.1
# Four       - 73.3
# Five       - 41.0
# Six        - 32.0
# Seven      - 39.3
# Eight      - 10.9
# Nine       - 39.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.296872
#
# Average test loss: 0.7315, Test accuracy: 8368/10000 (83.68%)
#
# Class      - Accuracy
# Zero       - 96.5
# One        - 97.5
# Two        - 90.9
# Three      - 85.3
# Four       - 92.9
# Five       - 75.9
# Six        - 88.0
# Seven      - 80.4
# Eight      - 56.4
# Nine       - 70.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.788100
#
# Average test loss: 0.4114, Test accuracy: 8945/10000 (89.45%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.4
# Two        - 93.3
# Three      - 88.7
# Four       - 96.9
# Five       - 88.9
# Six        - 94.1
# Seven      - 82.0
# Eight      - 75.3
# Nine       - 77.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.617327
#
# Average test loss: 0.3050, Test accuracy: 9220/10000 (92.20%)
#
# Class      - Accuracy
# Zero       - 97.6
# One        - 98.9
# Two        - 94.1
# Three      - 90.1
# Four       - 95.9
# Five       - 91.9
# Six        - 96.1
# Seven      - 84.0
# Eight      - 82.0
# Nine       - 90.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.525266
#
# Average test loss: 0.2462, Test accuracy: 9328/10000 (93.28%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.8
# Two        - 94.0
# Three      - 91.7
# Four       - 97.0
# Five       - 94.2
# Six        - 95.9
# Seven      - 86.9
# Eight      - 85.6
# Nine       - 90.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.470004
#
# Average test loss: 0.2150, Test accuracy: 9406/10000 (94.06%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 95.3
# Three      - 92.3
# Four       - 97.0
# Five       - 96.6
# Six        - 96.7
# Seven      - 87.7
# Eight      - 86.2
# Nine       - 91.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.433255
#
# Average test loss: 0.1883, Test accuracy: 9452/10000 (94.52%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.9
# Two        - 95.7
# Three      - 92.8
# Four       - 96.9
# Five       - 95.7
# Six        - 97.0
# Seven      - 88.7
# Eight      - 88.7
# Nine       - 92.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.403727
#
# Average test loss: 0.1753, Test accuracy: 9489/10000 (94.89%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 95.5
# Three      - 94.3
# Four       - 96.9
# Five       - 96.9
# Six        - 97.0
# Seven      - 88.3
# Eight      - 88.4
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.379338
#
# Average test loss: 0.1618, Test accuracy: 9543/10000 (95.43%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 96.6
# Three      - 94.8
# Four       - 97.1
# Five       - 97.0
# Six        - 97.6
# Seven      - 89.7
# Eight      - 90.0
# Nine       - 94.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.362486
#
# Average test loss: 0.1535, Test accuracy: 9548/10000 (95.48%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 97.3
# Three      - 95.0
# Four       - 96.9
# Five       - 97.1
# Six        - 97.3
# Seven      - 89.4
# Eight      - 88.8
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.342742
#
# Average test loss: 0.1412, Test accuracy: 9580/10000 (95.80%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 97.4
# Three      - 95.7
# Four       - 97.1
# Five       - 97.4
# Six        - 97.4
# Seven      - 89.9
# Eight      - 90.1
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.326585
#
# Average test loss: 0.1327, Test accuracy: 9593/10000 (95.93%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 96.8
# Three      - 95.6
# Four       - 97.4
# Five       - 97.6
# Six        - 97.5
# Seven      - 90.7
# Eight      - 91.2
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.307068
#
# Average test loss: 0.1237, Test accuracy: 9620/10000 (96.20%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 96.5
# Three      - 95.8
# Four       - 97.1
# Five       - 97.9
# Six        - 97.6
# Seven      - 91.8
# Eight      - 92.2
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.297757
#
# Average test loss: 0.1216, Test accuracy: 9634/10000 (96.34%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 97.4
# Three      - 96.0
# Four       - 97.3
# Five       - 97.9
# Six        - 97.7
# Seven      - 91.6
# Eight      - 92.0
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.291763
#
# Average test loss: 0.1182, Test accuracy: 9641/10000 (96.41%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 98.0
# Three      - 96.3
# Four       - 96.9
# Five       - 98.2
# Six        - 97.7
# Seven      - 91.1
# Eight      - 92.9
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.282484
#
# Average test loss: 0.1107, Test accuracy: 9658/10000 (96.58%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 97.6
# Three      - 96.3
# Four       - 97.4
# Five       - 98.2
# Six        - 97.8
# Seven      - 92.1
# Eight      - 93.1
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.273365
#
# Average test loss: 0.1076, Test accuracy: 9663/10000 (96.63%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 97.9
# Three      - 96.2
# Four       - 97.9
# Five       - 98.2
# Six        - 97.7
# Seven      - 92.0
# Eight      - 93.3
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.268401
#
# Average test loss: 0.1049, Test accuracy: 9674/10000 (96.74%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 98.2
# Three      - 96.5
# Four       - 97.3
# Five       - 98.1
# Six        - 97.9
# Seven      - 92.0
# Eight      - 93.4
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.261311
#
# Average test loss: 0.1014, Test accuracy: 9682/10000 (96.82%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 98.1
# Three      - 96.4
# Four       - 97.3
# Five       - 98.3
# Six        - 97.5
# Seven      - 92.9
# Eight      - 93.6
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.248880
#
# Average test loss: 0.1000, Test accuracy: 9687/10000 (96.87%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.8
# Two        - 98.2
# Three      - 96.7
# Four       - 97.4
# Five       - 98.3
# Six        - 97.6
# Seven      - 92.8
# Eight      - 93.7
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.246287
#
# Average test loss: 0.0976, Test accuracy: 9683/10000 (96.83%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 97.9
# Three      - 96.6
# Four       - 97.7
# Five       - 98.7
# Six        - 97.6
# Seven      - 93.0
# Eight      - 93.1
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.242366
#
# Average test loss: 0.0910, Test accuracy: 9716/10000 (97.16%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 97.8
# Three      - 96.8
# Four       - 97.7
# Five       - 98.3
# Six        - 97.9
# Seven      - 94.4
# Eight      - 94.8
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.241546
#
# Average test loss: 0.0953, Test accuracy: 9702/10000 (97.02%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 98.2
# Three      - 96.0
# Four       - 97.7
# Five       - 98.8
# Six        - 98.2
# Seven      - 93.1
# Eight      - 94.7
# Nine       - 96.2
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.229852
#
# Average test loss: 0.0905, Test accuracy: 9724/10000 (97.24%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 98.3
# Three      - 96.3
# Four       - 98.0
# Five       - 98.4
# Six        - 98.0
# Seven      - 93.6
# Eight      - 95.0
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.230879
#
# Average test loss: 0.0855, Test accuracy: 9732/10000 (97.32%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 98.4
# Three      - 96.8
# Four       - 98.0
# Five       - 98.3
# Six        - 97.7
# Seven      - 93.7
# Eight      - 96.0
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.219371
#
# Average test loss: 0.0853, Test accuracy: 9729/10000 (97.29%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 98.6
# Three      - 96.8
# Four       - 97.7
# Five       - 98.7
# Six        - 97.8
# Seven      - 93.8
# Eight      - 95.5
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.224714
#
# Average test loss: 0.0827, Test accuracy: 9750/10000 (97.50%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.2
# Two        - 98.4
# Three      - 96.9
# Four       - 98.0
# Five       - 98.8
# Six        - 97.4
# Seven      - 94.9
# Eight      - 95.4
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.220599
#
# Average test loss: 0.0821, Test accuracy: 9739/10000 (97.39%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.9
# Two        - 98.6
# Three      - 97.0
# Four       - 97.8
# Five       - 98.8
# Six        - 97.7
# Seven      - 94.0
# Eight      - 95.6
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.215331
#
# Average test loss: 0.0797, Test accuracy: 9757/10000 (97.57%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 98.8
# Three      - 97.0
# Four       - 98.4
# Five       - 98.7
# Six        - 98.2
# Seven      - 94.1
# Eight      - 95.9
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.210860
#
# Average test loss: 0.0805, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 98.5
# Three      - 97.1
# Four       - 98.3
# Five       - 98.5
# Six        - 98.2
# Seven      - 94.1
# Eight      - 95.8
# Nine       - 96.6
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0860, Test accuracy: 9733/10000 (97.33%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 98.4
# Three      - 96.7
# Four       - 97.9
# Five       - 98.5
# Six        - 97.9
# Seven      - 94.0
# Eight      - 95.5
# Nine       - 96.5
# Global accuracies:  [53.0, 83.68, 89.45, 92.2, 93.28, 94.06, 94.52, 94.89, 95.43, 95.48, 95.8, 95.93, 96.2, 96.34, 96.41, 96.58, 96.63, 96.74, 96.82, 96.87, 96.83, 97.16, 97.02, 97.24, 97.32, 97.29, 97.5, 97.39, 97.57, 97.54, 97.33]
# Class 2 accuracies:  [98.74, 90.89, 93.31, 94.09, 93.99, 95.25, 95.74, 95.54, 96.61, 97.29, 97.38, 96.8, 96.51, 97.38, 97.97, 97.58, 97.87, 98.16, 98.06, 98.16, 97.87, 97.77, 98.16, 98.26, 98.45, 98.64, 98.45, 98.64, 98.84, 98.55, 98.45]
# Test loss: [2.0245, 0.7315, 0.4114, 0.305, 0.2462, 0.215, 0.1883, 0.1753, 0.1618, 0.1535, 0.1412, 0.1327, 0.1237, 0.1216, 0.1182, 0.1107, 0.1076, 0.1049, 0.1014, 0.1, 0.0976, 0.091, 0.0953, 0.0905, 0.0855, 0.0853, 0.0827, 0.0821, 0.0797, 0.0805, 0.086]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.013684376080830892
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: median
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.891990
#
# Average test loss: 2.0314, Test accuracy: 5301/10000 (53.01%)
#
# Class      - Accuracy
# Zero       - 30.0
# One        - 84.0
# Two        - 98.4
# Three      - 66.9
# Four       - 78.2
# Five       - 60.1
# Six        - 24.0
# Seven      - 38.5
# Eight      - 14.1
# Nine       - 29.3
#
# Backdoor ASR 0.48
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.312545
#
# Average test loss: 0.7261, Test accuracy: 8354/10000 (83.54%)
#
# Class      - Accuracy
# Zero       - 95.8
# One        - 97.9
# Two        - 89.9
# Three      - 80.4
# Four       - 91.6
# Five       - 79.7
# Six        - 88.2
# Seven      - 76.1
# Eight      - 61.6
# Nine       - 72.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.802487
#
# Average test loss: 0.4217, Test accuracy: 9021/10000 (90.21%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.5
# Two        - 93.1
# Three      - 88.0
# Four       - 92.8
# Five       - 87.8
# Six        - 94.8
# Seven      - 84.6
# Eight      - 75.9
# Nine       - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.636468
#
# Average test loss: 0.3123, Test accuracy: 9180/10000 (91.80%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.7
# Two        - 93.1
# Three      - 90.1
# Four       - 97.1
# Five       - 91.0
# Six        - 96.0
# Seven      - 85.8
# Eight      - 80.8
# Nine       - 86.6
#
# Backdoor ASR 0.1
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.550435
#
# Average test loss: 0.2552, Test accuracy: 9311/10000 (93.11%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.8
# Two        - 93.9
# Three      - 93.2
# Four       - 95.8
# Five       - 92.2
# Six        - 95.9
# Seven      - 86.5
# Eight      - 83.7
# Nine       - 92.2
#
# Backdoor ASR 0.1
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.491311
#
# Average test loss: 0.2198, Test accuracy: 9374/10000 (93.74%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 95.0
# Three      - 92.9
# Four       - 97.0
# Five       - 94.5
# Six        - 96.7
# Seven      - 85.8
# Eight      - 85.9
# Nine       - 92.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.457055
#
# Average test loss: 0.1899, Test accuracy: 9458/10000 (94.58%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 94.9
# Three      - 92.7
# Four       - 96.6
# Five       - 96.5
# Six        - 96.7
# Seven      - 88.9
# Eight      - 89.1
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.424194
#
# Average test loss: 0.1778, Test accuracy: 9479/10000 (94.79%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 95.7
# Three      - 93.8
# Four       - 96.9
# Five       - 95.7
# Six        - 97.3
# Seven      - 88.6
# Eight      - 88.5
# Nine       - 93.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.400668
#
# Average test loss: 0.1642, Test accuracy: 9522/10000 (95.22%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 96.2
# Three      - 94.6
# Four       - 97.0
# Five       - 96.5
# Six        - 97.6
# Seven      - 89.5
# Eight      - 89.2
# Nine       - 93.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.375054
#
# Average test loss: 0.1510, Test accuracy: 9553/10000 (95.53%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.1
# Three      - 95.2
# Four       - 97.1
# Five       - 96.9
# Six        - 97.5
# Seven      - 90.1
# Eight      - 90.0
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.361283
#
# Average test loss: 0.1394, Test accuracy: 9573/10000 (95.73%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.1
# Three      - 95.6
# Four       - 97.1
# Five       - 96.9
# Six        - 97.3
# Seven      - 90.5
# Eight      - 91.1
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.343843
#
# Average test loss: 0.1337, Test accuracy: 9592/10000 (95.92%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 96.8
# Three      - 95.4
# Four       - 97.3
# Five       - 97.6
# Six        - 97.3
# Seven      - 89.7
# Eight      - 92.9
# Nine       - 94.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.339206
#
# Average test loss: 0.1283, Test accuracy: 9613/10000 (96.13%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.4
# Three      - 96.5
# Four       - 97.0
# Five       - 97.5
# Six        - 97.5
# Seven      - 90.4
# Eight      - 91.7
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.324208
#
# Average test loss: 0.1209, Test accuracy: 9632/10000 (96.32%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.6
# Three      - 95.8
# Four       - 97.3
# Five       - 97.6
# Six        - 97.6
# Seven      - 91.7
# Eight      - 92.4
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.320228
#
# Average test loss: 0.1176, Test accuracy: 9647/10000 (96.47%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 97.7
# Three      - 96.5
# Four       - 97.5
# Five       - 97.9
# Six        - 97.5
# Seven      - 91.5
# Eight      - 93.0
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.306052
#
# Average test loss: 0.1136, Test accuracy: 9656/10000 (96.56%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.7
# Three      - 96.1
# Four       - 97.4
# Five       - 98.3
# Six        - 97.4
# Seven      - 92.5
# Eight      - 92.4
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.291867
#
# Average test loss: 0.1071, Test accuracy: 9667/10000 (96.67%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 97.6
# Three      - 96.5
# Four       - 97.3
# Five       - 98.3
# Six        - 97.3
# Seven      - 92.7
# Eight      - 93.2
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.298015
#
# Average test loss: 0.1038, Test accuracy: 9678/10000 (96.78%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 97.7
# Three      - 97.2
# Four       - 96.9
# Five       - 98.3
# Six        - 97.7
# Seven      - 92.5
# Eight      - 93.6
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.284097
#
# Average test loss: 0.1012, Test accuracy: 9683/10000 (96.83%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.7
# Three      - 96.6
# Four       - 97.5
# Five       - 98.2
# Six        - 97.6
# Seven      - 93.3
# Eight      - 93.4
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.276876
#
# Average test loss: 0.1013, Test accuracy: 9692/10000 (96.92%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 98.0
# Three      - 96.9
# Four       - 97.3
# Five       - 98.2
# Six        - 97.7
# Seven      - 93.1
# Eight      - 93.7
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.279905
#
# Average test loss: 0.0958, Test accuracy: 9706/10000 (97.06%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 97.8
# Three      - 96.7
# Four       - 97.4
# Five       - 98.5
# Six        - 97.8
# Seven      - 93.4
# Eight      - 94.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.269628
#
# Average test loss: 0.0943, Test accuracy: 9703/10000 (97.03%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 97.8
# Three      - 97.1
# Four       - 97.3
# Five       - 98.4
# Six        - 97.6
# Seven      - 93.4
# Eight      - 94.0
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.267419
#
# Average test loss: 0.0915, Test accuracy: 9714/10000 (97.14%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 98.2
# Three      - 96.9
# Four       - 97.7
# Five       - 98.4
# Six        - 98.0
# Seven      - 93.4
# Eight      - 94.8
# Nine       - 96.1
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.261941
#
# Average test loss: 0.0873, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.8
# Three      - 97.1
# Four       - 98.0
# Five       - 98.4
# Six        - 97.5
# Seven      - 94.3
# Eight      - 95.3
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.253075
#
# Average test loss: 0.0880, Test accuracy: 9716/10000 (97.16%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 98.0
# Three      - 97.2
# Four       - 97.1
# Five       - 98.4
# Six        - 98.2
# Seven      - 93.4
# Eight      - 94.9
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.250226
#
# Average test loss: 0.0865, Test accuracy: 9721/10000 (97.21%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 97.8
# Three      - 97.2
# Four       - 97.4
# Five       - 98.4
# Six        - 97.9
# Seven      - 94.0
# Eight      - 94.9
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.248436
#
# Average test loss: 0.0842, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.3
# Three      - 97.0
# Four       - 97.6
# Five       - 98.5
# Six        - 97.5
# Seven      - 94.7
# Eight      - 94.4
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.244158
#
# Average test loss: 0.0831, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 98.2
# Three      - 97.1
# Four       - 97.9
# Five       - 98.7
# Six        - 98.4
# Seven      - 94.2
# Eight      - 95.4
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.244827
#
# Average test loss: 0.0806, Test accuracy: 9750/10000 (97.50%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 98.4
# Three      - 98.0
# Four       - 97.9
# Five       - 98.5
# Six        - 98.3
# Seven      - 94.3
# Eight      - 95.0
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.238411
#
# Average test loss: 0.0776, Test accuracy: 9755/10000 (97.55%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 98.4
# Three      - 97.7
# Four       - 97.9
# Five       - 98.5
# Six        - 98.4
# Seven      - 94.7
# Eight      - 95.2
# Nine       - 96.5
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0862, Test accuracy: 9734/10000 (97.34%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.1
# Three      - 97.3
# Four       - 97.7
# Five       - 98.4
# Six        - 98.2
# Seven      - 94.2
# Eight      - 95.0
# Nine       - 96.4
# Global accuracies:  [53.01, 83.54, 90.21, 91.8, 93.11, 93.74, 94.58, 94.79, 95.22, 95.53, 95.73, 95.92, 96.13, 96.32, 96.47, 96.56, 96.67, 96.78, 96.83, 96.92, 97.06, 97.03, 97.14, 97.27, 97.16, 97.21, 97.27, 97.43, 97.5, 97.55, 97.34]
# Class 2 accuracies:  [98.35, 89.92, 93.12, 93.12, 93.9, 94.96, 94.86, 95.74, 96.22, 96.12, 96.12, 96.8, 97.38, 97.58, 97.67, 97.67, 97.58, 97.67, 97.67, 97.97, 97.77, 97.77, 98.16, 97.77, 97.97, 97.77, 98.26, 98.16, 98.45, 98.45, 98.06]
# Test loss: [2.0314, 0.7261, 0.4217, 0.3123, 0.2552, 0.2198, 0.1899, 0.1778, 0.1642, 0.151, 0.1394, 0.1337, 0.1283, 0.1209, 0.1176, 0.1136, 0.1071, 0.1038, 0.1012, 0.1013, 0.0958, 0.0943, 0.0915, 0.0873, 0.088, 0.0865, 0.0842, 0.0831, 0.0806, 0.0776, 0.0862]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.013198550542195637
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: median
# Attack Type: backdoor
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.893803
#
# Average test loss: 2.0404, Test accuracy: 4773/10000 (47.73%)
#
# Class      - Accuracy
# Zero       - 12.7
# One        - 82.7
# Two        - 96.4
# Three      - 55.1
# Four       - 81.7
# Five       - 76.9
# Six        - 4.0
# Seven      - 35.7
# Eight      - 8.4
# Nine       - 18.1
#
# Backdoor ASR 2.62
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.335533
#
# Average test loss: 0.7880, Test accuracy: 8317/10000 (83.17%)
#
# Class      - Accuracy
# Zero       - 96.8
# One        - 98.5
# Two        - 86.0
# Three      - 80.5
# Four       - 91.0
# Five       - 77.9
# Six        - 87.0
# Seven      - 76.6
# Eight      - 56.0
# Nine       - 78.8
#
# Backdoor ASR 0.1
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.832729
#
# Average test loss: 0.4321, Test accuracy: 9000/10000 (90.00%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.3
# Two        - 92.4
# Three      - 88.7
# Four       - 95.0
# Five       - 90.7
# Six        - 94.4
# Seven      - 84.5
# Eight      - 72.1
# Nine       - 84.7
#
# Backdoor ASR 0.19
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.677838
#
# Average test loss: 0.3200, Test accuracy: 9198/10000 (91.98%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.7
# Two        - 92.7
# Three      - 89.8
# Four       - 96.8
# Five       - 91.9
# Six        - 95.7
# Seven      - 87.3
# Eight      - 81.0
# Nine       - 86.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.585715
#
# Average test loss: 0.2648, Test accuracy: 9294/10000 (92.94%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 94.3
# Three      - 91.8
# Four       - 96.2
# Five       - 92.9
# Six        - 96.3
# Seven      - 85.7
# Eight      - 83.4
# Nine       - 90.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.546191
#
# Average test loss: 0.2319, Test accuracy: 9364/10000 (93.64%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 94.2
# Three      - 93.0
# Four       - 96.4
# Five       - 94.8
# Six        - 96.8
# Seven      - 85.1
# Eight      - 86.2
# Nine       - 92.5
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.496835
#
# Average test loss: 0.1982, Test accuracy: 9431/10000 (94.31%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.9
# Two        - 94.4
# Three      - 93.6
# Four       - 97.3
# Five       - 95.3
# Six        - 97.6
# Seven      - 86.7
# Eight      - 89.7
# Nine       - 91.6
#
# Backdoor ASR 0.19
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.468656
#
# Average test loss: 0.1830, Test accuracy: 9476/10000 (94.76%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 94.7
# Three      - 94.2
# Four       - 96.6
# Five       - 95.9
# Six        - 97.4
# Seven      - 89.7
# Eight      - 87.8
# Nine       - 93.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.446213
#
# Average test loss: 0.1671, Test accuracy: 9514/10000 (95.14%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 95.6
# Three      - 93.8
# Four       - 97.0
# Five       - 96.7
# Six        - 97.5
# Seven      - 89.8
# Eight      - 90.0
# Nine       - 93.4
#
# Backdoor ASR 0.1
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.427012
#
# Average test loss: 0.1567, Test accuracy: 9540/10000 (95.40%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 95.4
# Three      - 95.3
# Four       - 97.1
# Five       - 97.2
# Six        - 97.7
# Seven      - 90.0
# Eight      - 89.7
# Nine       - 94.1
#
# Backdoor ASR 0.19
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.407232
#
# Average test loss: 0.1455, Test accuracy: 9559/10000 (95.59%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 95.9
# Three      - 95.4
# Four       - 97.4
# Five       - 97.0
# Six        - 97.7
# Seven      - 90.3
# Eight      - 90.6
# Nine       - 94.2
#
# Backdoor ASR 0.1
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.398638
#
# Average test loss: 0.1368, Test accuracy: 9586/10000 (95.86%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.3
# Three      - 95.5
# Four       - 97.1
# Five       - 97.3
# Six        - 97.7
# Seven      - 90.9
# Eight      - 91.4
# Nine       - 94.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.375303
#
# Average test loss: 0.1293, Test accuracy: 9608/10000 (96.08%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 97.1
# Three      - 95.7
# Four       - 97.0
# Five       - 97.2
# Six        - 97.7
# Seven      - 90.9
# Eight      - 92.2
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.367015
#
# Average test loss: 0.1228, Test accuracy: 9639/10000 (96.39%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.7
# Three      - 96.1
# Four       - 97.3
# Five       - 98.0
# Six        - 97.8
# Seven      - 92.3
# Eight      - 92.8
# Nine       - 95.2
#
# Backdoor ASR 0.1
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.363542
#
# Average test loss: 0.1175, Test accuracy: 9651/10000 (96.51%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.9
# Three      - 96.3
# Four       - 97.5
# Five       - 97.8
# Six        - 98.0
# Seven      - 91.8
# Eight      - 93.9
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.349030
#
# Average test loss: 0.1132, Test accuracy: 9652/10000 (96.52%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 97.4
# Three      - 96.0
# Four       - 97.4
# Five       - 98.2
# Six        - 97.7
# Seven      - 91.7
# Eight      - 93.8
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.352693
#
# Average test loss: 0.1129, Test accuracy: 9652/10000 (96.52%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.1
# Three      - 96.9
# Four       - 97.0
# Five       - 98.5
# Six        - 97.8
# Seven      - 91.5
# Eight      - 92.6
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.334382
#
# Average test loss: 0.1060, Test accuracy: 9677/10000 (96.77%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 97.2
# Three      - 96.8
# Four       - 97.8
# Five       - 98.7
# Six        - 97.7
# Seven      - 93.0
# Eight      - 93.0
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.332146
#
# Average test loss: 0.1024, Test accuracy: 9684/10000 (96.84%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 97.5
# Three      - 97.0
# Four       - 97.8
# Five       - 98.5
# Six        - 97.6
# Seven      - 93.1
# Eight      - 93.5
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.320673
#
# Average test loss: 0.1010, Test accuracy: 9694/10000 (96.94%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.9
# Three      - 96.7
# Four       - 97.4
# Five       - 98.3
# Six        - 97.9
# Seven      - 93.0
# Eight      - 94.0
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.324966
#
# Average test loss: 0.0971, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.6
# Three      - 97.3
# Four       - 97.6
# Five       - 98.5
# Six        - 97.8
# Seven      - 93.1
# Eight      - 94.5
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.319075
#
# Average test loss: 0.0942, Test accuracy: 9699/10000 (96.99%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 97.7
# Three      - 97.3
# Four       - 97.5
# Five       - 98.7
# Six        - 97.6
# Seven      - 93.2
# Eight      - 94.6
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.312473
#
# Average test loss: 0.0919, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 97.7
# Three      - 97.3
# Four       - 97.7
# Five       - 98.4
# Six        - 98.0
# Seven      - 92.9
# Eight      - 95.0
# Nine       - 95.9
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.306293
#
# Average test loss: 0.0917, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 97.6
# Three      - 97.3
# Four       - 97.6
# Five       - 98.7
# Six        - 98.1
# Seven      - 93.5
# Eight      - 94.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.299933
#
# Average test loss: 0.0870, Test accuracy: 9735/10000 (97.35%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.7
# Three      - 97.4
# Four       - 97.5
# Five       - 98.5
# Six        - 98.2
# Seven      - 94.4
# Eight      - 95.3
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.297650
#
# Average test loss: 0.0859, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 98.1
# Three      - 97.2
# Four       - 97.8
# Five       - 98.5
# Six        - 98.1
# Seven      - 93.9
# Eight      - 94.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.298758
#
# Average test loss: 0.0841, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.7
# Three      - 97.2
# Four       - 98.0
# Five       - 98.8
# Six        - 98.2
# Seven      - 94.8
# Eight      - 95.1
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.289077
#
# Average test loss: 0.0816, Test accuracy: 9750/10000 (97.50%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.8
# Three      - 97.5
# Four       - 98.1
# Five       - 98.5
# Six        - 98.4
# Seven      - 95.1
# Eight      - 95.3
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.286724
#
# Average test loss: 0.0821, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.3
# Three      - 97.0
# Four       - 97.9
# Five       - 98.7
# Six        - 98.2
# Seven      - 94.5
# Eight      - 95.3
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.282129
#
# Average test loss: 0.0812, Test accuracy: 9752/10000 (97.52%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.0
# Two        - 98.4
# Three      - 97.4
# Four       - 98.0
# Five       - 98.8
# Six        - 98.3
# Seven      - 94.3
# Eight      - 95.4
# Nine       - 96.5
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0869, Test accuracy: 9728/10000 (97.28%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.8
# Three      - 97.2
# Four       - 97.7
# Five       - 98.7
# Six        - 98.1
# Seven      - 94.1
# Eight      - 95.0
# Nine       - 96.3
# Global accuracies:  [47.73, 83.17, 90.0, 91.98, 92.94, 93.64, 94.31, 94.76, 95.14, 95.4, 95.59, 95.86, 96.08, 96.39, 96.51, 96.52, 96.52, 96.77, 96.84, 96.94, 97.0, 96.99, 97.09, 97.19, 97.35, 97.27, 97.43, 97.5, 97.41, 97.52, 97.28]
# Class 2 accuracies:  [96.41, 86.05, 92.44, 92.73, 94.28, 94.19, 94.38, 94.67, 95.64, 95.45, 95.93, 96.32, 97.09, 96.71, 96.9, 97.38, 97.09, 97.19, 97.48, 97.87, 97.58, 97.67, 97.67, 97.58, 97.67, 98.06, 97.67, 97.77, 98.26, 98.35, 97.77]
# Test loss: [2.0404, 0.788, 0.4321, 0.32, 0.2648, 0.2319, 0.1982, 0.183, 0.1671, 0.1567, 0.1455, 0.1368, 0.1293, 0.1228, 0.1175, 0.1132, 0.1129, 0.106, 0.1024, 0.101, 0.0971, 0.0942, 0.0919, 0.0917, 0.087, 0.0859, 0.0841, 0.0816, 0.0821, 0.0812, 0.0869]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.013099098205566406
#
# --> End of Experiment.

# %%
RULE = 'tmean'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: tmean
# Attack Type: backdoor
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.885372
#
# Average test loss: 1.8726, Test accuracy: 6801/10000 (68.01%)
#
# Class      - Accuracy
# Zero       - 68.1
# One        - 94.2
# Two        - 92.2
# Three      - 88.0
# Four       - 84.7
# Five       - 24.6
# Six        - 72.8
# Seven      - 64.4
# Eight      - 31.7
# Nine       - 50.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.176012
#
# Average test loss: 0.6227, Test accuracy: 8540/10000 (85.40%)
#
# Class      - Accuracy
# Zero       - 96.9
# One        - 98.3
# Two        - 90.2
# Three      - 88.6
# Four       - 93.5
# Five       - 70.2
# Six        - 91.0
# Seven      - 81.7
# Eight      - 63.8
# Nine       - 76.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.720402
#
# Average test loss: 0.3685, Test accuracy: 9035/10000 (90.35%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.6
# Two        - 93.4
# Three      - 89.3
# Four       - 96.8
# Five       - 88.7
# Six        - 94.6
# Seven      - 84.4
# Eight      - 77.0
# Nine       - 81.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.566080
#
# Average test loss: 0.2746, Test accuracy: 9274/10000 (92.74%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.9
# Two        - 93.4
# Three      - 91.4
# Four       - 96.2
# Five       - 93.0
# Six        - 96.8
# Seven      - 85.9
# Eight      - 82.2
# Nine       - 91.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.481191
#
# Average test loss: 0.2201, Test accuracy: 9397/10000 (93.97%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.9
# Two        - 94.8
# Three      - 92.6
# Four       - 96.7
# Five       - 95.0
# Six        - 96.8
# Seven      - 88.3
# Eight      - 86.7
# Nine       - 91.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.427101
#
# Average test loss: 0.1966, Test accuracy: 9448/10000 (94.48%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 95.2
# Three      - 93.1
# Four       - 97.3
# Five       - 96.2
# Six        - 96.9
# Seven      - 89.6
# Eight      - 87.3
# Nine       - 92.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.395094
#
# Average test loss: 0.1743, Test accuracy: 9512/10000 (95.12%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.0
# Two        - 95.6
# Three      - 94.0
# Four       - 96.9
# Five       - 96.5
# Six        - 97.3
# Seven      - 90.5
# Eight      - 89.0
# Nine       - 94.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.369412
#
# Average test loss: 0.1627, Test accuracy: 9535/10000 (95.35%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.6
# Three      - 95.5
# Four       - 97.0
# Five       - 97.1
# Six        - 97.3
# Seven      - 89.6
# Eight      - 89.3
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.346209
#
# Average test loss: 0.1475, Test accuracy: 9577/10000 (95.77%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 97.0
# Three      - 95.4
# Four       - 97.1
# Five       - 96.7
# Six        - 97.8
# Seven      - 91.1
# Eight      - 90.6
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.333510
#
# Average test loss: 0.1384, Test accuracy: 9588/10000 (95.88%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 97.1
# Three      - 95.3
# Four       - 96.9
# Five       - 97.4
# Six        - 97.5
# Seven      - 90.3
# Eight      - 91.3
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.313364
#
# Average test loss: 0.1306, Test accuracy: 9609/10000 (96.09%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.1
# Three      - 96.0
# Four       - 97.1
# Five       - 97.4
# Six        - 97.5
# Seven      - 91.3
# Eight      - 91.2
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.299319
#
# Average test loss: 0.1222, Test accuracy: 9622/10000 (96.22%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 97.1
# Three      - 95.7
# Four       - 97.4
# Five       - 97.9
# Six        - 97.7
# Seven      - 91.7
# Eight      - 91.9
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.282365
#
# Average test loss: 0.1148, Test accuracy: 9650/10000 (96.50%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.0
# Two        - 96.8
# Three      - 96.1
# Four       - 97.3
# Five       - 98.1
# Six        - 98.0
# Seven      - 93.5
# Eight      - 92.4
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.274714
#
# Average test loss: 0.1107, Test accuracy: 9665/10000 (96.65%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.9
# Three      - 96.1
# Four       - 97.4
# Five       - 97.9
# Six        - 98.0
# Seven      - 93.1
# Eight      - 93.5
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.265563
#
# Average test loss: 0.1072, Test accuracy: 9671/10000 (96.71%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 97.9
# Three      - 96.6
# Four       - 96.8
# Five       - 98.3
# Six        - 97.9
# Seven      - 92.4
# Eight      - 93.5
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.257586
#
# Average test loss: 0.1010, Test accuracy: 9686/10000 (96.86%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 97.9
# Three      - 96.5
# Four       - 97.5
# Five       - 98.4
# Six        - 97.6
# Seven      - 93.4
# Eight      - 93.5
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.251402
#
# Average test loss: 0.0980, Test accuracy: 9698/10000 (96.98%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.3
# Two        - 98.0
# Three      - 96.4
# Four       - 97.9
# Five       - 98.5
# Six        - 97.9
# Seven      - 93.3
# Eight      - 94.1
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.248052
#
# Average test loss: 0.0944, Test accuracy: 9722/10000 (97.22%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 98.4
# Three      - 96.7
# Four       - 97.7
# Five       - 98.4
# Six        - 98.2
# Seven      - 93.9
# Eight      - 95.0
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.238067
#
# Average test loss: 0.0912, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 97.9
# Three      - 97.0
# Four       - 97.3
# Five       - 98.7
# Six        - 97.8
# Seven      - 94.2
# Eight      - 95.1
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.230431
#
# Average test loss: 0.0884, Test accuracy: 9730/10000 (97.30%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 98.2
# Three      - 97.0
# Four       - 97.5
# Five       - 98.7
# Six        - 97.9
# Seven      - 94.7
# Eight      - 94.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.228043
#
# Average test loss: 0.0887, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 98.1
# Three      - 97.0
# Four       - 97.6
# Five       - 98.7
# Six        - 97.8
# Seven      - 94.4
# Eight      - 95.0
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.225164
#
# Average test loss: 0.0827, Test accuracy: 9746/10000 (97.46%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 97.9
# Three      - 97.0
# Four       - 97.7
# Five       - 98.7
# Six        - 98.0
# Seven      - 95.4
# Eight      - 95.7
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.223121
#
# Average test loss: 0.0857, Test accuracy: 9738/10000 (97.38%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 98.3
# Three      - 96.8
# Four       - 97.8
# Five       - 98.8
# Six        - 98.3
# Seven      - 94.5
# Eight      - 95.4
# Nine       - 96.2
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.211713
#
# Average test loss: 0.0813, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 98.5
# Three      - 96.9
# Four       - 97.8
# Five       - 98.8
# Six        - 98.0
# Seven      - 95.1
# Eight      - 95.5
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.210619
#
# Average test loss: 0.0778, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 98.4
# Three      - 97.1
# Four       - 97.9
# Five       - 98.8
# Six        - 98.0
# Seven      - 95.1
# Eight      - 96.1
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.204000
#
# Average test loss: 0.0771, Test accuracy: 9762/10000 (97.62%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 98.6
# Three      - 97.0
# Four       - 97.3
# Five       - 99.0
# Six        - 98.3
# Seven      - 95.0
# Eight      - 96.0
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.207190
#
# Average test loss: 0.0752, Test accuracy: 9759/10000 (97.59%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.5
# Two        - 98.2
# Three      - 96.9
# Four       - 97.8
# Five       - 98.9
# Six        - 97.8
# Seven      - 95.4
# Eight      - 95.7
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.201253
#
# Average test loss: 0.0738, Test accuracy: 9772/10000 (97.72%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.5
# Three      - 97.3
# Four       - 98.0
# Five       - 98.9
# Six        - 98.2
# Seven      - 95.2
# Eight      - 96.1
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.199752
#
# Average test loss: 0.0708, Test accuracy: 9782/10000 (97.82%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 98.7
# Three      - 97.5
# Four       - 98.5
# Five       - 98.9
# Six        - 98.1
# Seven      - 95.2
# Eight      - 96.2
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.194132
#
# Average test loss: 0.0716, Test accuracy: 9778/10000 (97.78%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.5
# Two        - 98.5
# Three      - 97.5
# Four       - 98.5
# Five       - 98.9
# Six        - 98.0
# Seven      - 95.3
# Eight      - 95.7
# Nine       - 96.8
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0777, Test accuracy: 9758/10000 (97.58%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.4
# Three      - 97.0
# Four       - 98.0
# Five       - 98.9
# Six        - 98.0
# Seven      - 95.1
# Eight      - 95.8
# Nine       - 96.4
# Global accuracies:  [68.01, 85.4, 90.35, 92.74, 93.97, 94.48, 95.12, 95.35, 95.77, 95.88, 96.09, 96.22, 96.5, 96.65, 96.71, 96.86, 96.98, 97.22, 97.19, 97.3, 97.27, 97.46, 97.38, 97.53, 97.6, 97.62, 97.59, 97.72, 97.82, 97.78, 97.58]
# Class 2 accuracies:  [92.25, 90.21, 93.41, 93.41, 94.77, 95.16, 95.64, 95.64, 97.0, 97.09, 97.09, 97.09, 96.8, 96.9, 97.87, 97.87, 97.97, 98.35, 97.87, 98.16, 98.06, 97.87, 98.26, 98.55, 98.35, 98.64, 98.16, 98.55, 98.74, 98.55, 98.35]
# Test loss: [1.8726, 0.6227, 0.3685, 0.2746, 0.2201, 0.1966, 0.1743, 0.1627, 0.1475, 0.1384, 0.1306, 0.1222, 0.1148, 0.1107, 0.1072, 0.101, 0.098, 0.0944, 0.0912, 0.0884, 0.0887, 0.0827, 0.0857, 0.0813, 0.0778, 0.0771, 0.0752, 0.0738, 0.0708, 0.0716, 0.0777]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.002367703119913737
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: tmean
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.892078
#
# Average test loss: 1.9483, Test accuracy: 6398/10000 (63.98%)
#
# Class      - Accuracy
# Zero       - 55.3
# One        - 89.8
# Two        - 95.6
# Three      - 81.5
# Four       - 82.2
# Five       - 52.0
# Six        - 59.0
# Seven      - 55.7
# Eight      - 22.0
# Nine       - 40.0
#
# Backdoor ASR 0.39
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.243588
#
# Average test loss: 0.6588, Test accuracy: 8499/10000 (84.99%)
#
# Class      - Accuracy
# Zero       - 95.8
# One        - 98.1
# Two        - 90.1
# Three      - 85.6
# Four       - 91.1
# Five       - 77.7
# Six        - 91.4
# Seven      - 77.7
# Eight      - 62.2
# Nine       - 77.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.767590
#
# Average test loss: 0.3996, Test accuracy: 9048/10000 (90.48%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.7
# Two        - 92.7
# Three      - 90.2
# Four       - 94.5
# Five       - 87.7
# Six        - 95.4
# Seven      - 85.1
# Eight      - 75.3
# Nine       - 86.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.610954
#
# Average test loss: 0.2963, Test accuracy: 9224/10000 (92.24%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.7
# Two        - 93.2
# Three      - 91.7
# Four       - 96.6
# Five       - 90.7
# Six        - 96.6
# Seven      - 86.6
# Eight      - 81.9
# Nine       - 87.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.527124
#
# Average test loss: 0.2403, Test accuracy: 9349/10000 (93.49%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 93.8
# Three      - 93.6
# Four       - 95.8
# Five       - 92.5
# Six        - 96.2
# Seven      - 88.2
# Eight      - 84.1
# Nine       - 92.8
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.467982
#
# Average test loss: 0.2086, Test accuracy: 9403/10000 (94.03%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 94.7
# Three      - 93.4
# Four       - 96.9
# Five       - 94.6
# Six        - 97.1
# Seven      - 86.8
# Eight      - 87.0
# Nine       - 92.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.434754
#
# Average test loss: 0.1824, Test accuracy: 9480/10000 (94.80%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 95.2
# Three      - 93.8
# Four       - 96.3
# Five       - 96.0
# Six        - 97.3
# Seven      - 89.0
# Eight      - 89.4
# Nine       - 93.6
#
# Backdoor ASR 0.1
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.402493
#
# Average test loss: 0.1677, Test accuracy: 9524/10000 (95.24%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 95.6
# Three      - 94.8
# Four       - 96.6
# Five       - 96.2
# Six        - 97.6
# Seven      - 90.0
# Eight      - 89.3
# Nine       - 94.4
#
# Backdoor ASR 0.1
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.380664
#
# Average test loss: 0.1551, Test accuracy: 9549/10000 (95.49%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.1
# Three      - 95.3
# Four       - 97.0
# Five       - 97.1
# Six        - 97.7
# Seven      - 90.0
# Eight      - 89.5
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.356933
#
# Average test loss: 0.1429, Test accuracy: 9574/10000 (95.74%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.0
# Three      - 95.4
# Four       - 96.9
# Five       - 97.5
# Six        - 97.5
# Seven      - 90.9
# Eight      - 90.6
# Nine       - 94.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.342866
#
# Average test loss: 0.1326, Test accuracy: 9598/10000 (95.98%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.4
# Three      - 95.8
# Four       - 97.1
# Five       - 97.3
# Six        - 97.4
# Seven      - 91.4
# Eight      - 91.5
# Nine       - 95.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.325794
#
# Average test loss: 0.1262, Test accuracy: 9615/10000 (96.15%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.4
# Three      - 95.4
# Four       - 97.1
# Five       - 98.0
# Six        - 97.3
# Seven      - 91.1
# Eight      - 93.3
# Nine       - 95.1
#
# Backdoor ASR 0.1
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.322761
#
# Average test loss: 0.1221, Test accuracy: 9628/10000 (96.28%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 97.5
# Three      - 96.1
# Four       - 97.1
# Five       - 97.6
# Six        - 97.7
# Seven      - 91.2
# Eight      - 92.2
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.308873
#
# Average test loss: 0.1141, Test accuracy: 9657/10000 (96.57%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 97.3
# Three      - 96.1
# Four       - 97.3
# Five       - 98.0
# Six        - 97.9
# Seven      - 92.5
# Eight      - 93.3
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.304423
#
# Average test loss: 0.1114, Test accuracy: 9660/10000 (96.60%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 97.3
# Three      - 96.7
# Four       - 97.5
# Five       - 98.1
# Six        - 97.8
# Seven      - 91.8
# Eight      - 92.9
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.289640
#
# Average test loss: 0.1065, Test accuracy: 9684/10000 (96.84%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 97.9
# Three      - 96.5
# Four       - 97.3
# Five       - 98.2
# Six        - 97.8
# Seven      - 93.5
# Eight      - 93.4
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.277670
#
# Average test loss: 0.0999, Test accuracy: 9701/10000 (97.01%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 97.8
# Three      - 97.0
# Four       - 97.5
# Five       - 98.2
# Six        - 98.0
# Seven      - 94.2
# Eight      - 93.9
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.282800
#
# Average test loss: 0.0971, Test accuracy: 9705/10000 (97.05%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 97.7
# Three      - 97.0
# Four       - 97.3
# Five       - 98.3
# Six        - 98.3
# Seven      - 93.8
# Eight      - 94.1
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.269648
#
# Average test loss: 0.0949, Test accuracy: 9715/10000 (97.15%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 97.8
# Three      - 97.1
# Four       - 97.6
# Five       - 98.5
# Six        - 98.1
# Seven      - 94.2
# Eight      - 93.9
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.264296
#
# Average test loss: 0.0941, Test accuracy: 9718/10000 (97.18%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 97.7
# Three      - 97.2
# Four       - 97.5
# Five       - 98.5
# Six        - 98.2
# Seven      - 94.4
# Eight      - 93.9
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.265329
#
# Average test loss: 0.0894, Test accuracy: 9735/10000 (97.35%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.5
# Two        - 97.7
# Three      - 96.9
# Four       - 97.5
# Five       - 98.5
# Six        - 98.1
# Seven      - 94.9
# Eight      - 95.2
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.256989
#
# Average test loss: 0.0881, Test accuracy: 9732/10000 (97.32%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.7
# Three      - 97.1
# Four       - 97.3
# Five       - 98.5
# Six        - 98.1
# Seven      - 94.6
# Eight      - 95.1
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.254451
#
# Average test loss: 0.0858, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.4
# Two        - 98.2
# Three      - 97.1
# Four       - 97.9
# Five       - 98.9
# Six        - 98.1
# Seven      - 94.6
# Eight      - 95.3
# Nine       - 96.2
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.247549
#
# Average test loss: 0.0824, Test accuracy: 9749/10000 (97.49%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 97.9
# Three      - 97.3
# Four       - 97.9
# Five       - 98.7
# Six        - 98.3
# Seven      - 95.0
# Eight      - 95.5
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.240421
#
# Average test loss: 0.0823, Test accuracy: 9751/10000 (97.51%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 98.0
# Three      - 97.2
# Four       - 97.5
# Five       - 98.8
# Six        - 98.6
# Seven      - 94.9
# Eight      - 95.4
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.237253
#
# Average test loss: 0.0815, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.3
# Two        - 98.1
# Three      - 97.2
# Four       - 97.7
# Five       - 98.7
# Six        - 98.0
# Seven      - 94.9
# Eight      - 95.1
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.236281
#
# Average test loss: 0.0791, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 98.2
# Three      - 97.1
# Four       - 97.9
# Five       - 98.8
# Six        - 98.3
# Seven      - 95.1
# Eight      - 95.0
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.230046
#
# Average test loss: 0.0774, Test accuracy: 9764/10000 (97.64%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 98.2
# Three      - 97.4
# Four       - 98.1
# Five       - 98.7
# Six        - 98.7
# Seven      - 95.0
# Eight      - 95.5
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.232234
#
# Average test loss: 0.0759, Test accuracy: 9766/10000 (97.66%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.4
# Three      - 97.5
# Four       - 97.8
# Five       - 98.9
# Six        - 98.5
# Seven      - 94.7
# Eight      - 95.7
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.228062
#
# Average test loss: 0.0730, Test accuracy: 9769/10000 (97.69%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 98.4
# Three      - 97.6
# Four       - 98.2
# Five       - 98.9
# Six        - 98.4
# Seven      - 95.1
# Eight      - 95.6
# Nine       - 96.5
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0808, Test accuracy: 9753/10000 (97.53%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 98.0
# Three      - 97.2
# Four       - 97.7
# Five       - 98.8
# Six        - 98.4
# Seven      - 95.1
# Eight      - 95.4
# Nine       - 96.6
# Global accuracies:  [63.98, 84.99, 90.48, 92.24, 93.49, 94.03, 94.8, 95.24, 95.49, 95.74, 95.98, 96.15, 96.28, 96.57, 96.6, 96.84, 97.01, 97.05, 97.15, 97.18, 97.35, 97.32, 97.44, 97.49, 97.51, 97.43, 97.53, 97.64, 97.66, 97.69, 97.53]
# Class 2 accuracies:  [95.64, 90.12, 92.73, 93.22, 93.8, 94.67, 95.16, 95.64, 96.12, 96.03, 96.41, 96.41, 97.48, 97.29, 97.29, 97.87, 97.77, 97.67, 97.77, 97.67, 97.67, 97.67, 98.16, 97.87, 97.97, 98.06, 98.16, 98.16, 98.45, 98.35, 97.97]
# Test loss: [1.9483, 0.6588, 0.3996, 0.2963, 0.2403, 0.2086, 0.1824, 0.1677, 0.1551, 0.1429, 0.1326, 0.1262, 0.1221, 0.1141, 0.1114, 0.1065, 0.0999, 0.0971, 0.0949, 0.0941, 0.0894, 0.0881, 0.0858, 0.0824, 0.0823, 0.0815, 0.0791, 0.0774, 0.0759, 0.073, 0.0808]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.014383737246195476
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: tmean
# Attack Type: backdoor
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.893784
#
# Average test loss: 1.9988, Test accuracy: 5375/10000 (53.75%)
#
# Class      - Accuracy
# Zero       - 28.5
# One        - 85.8
# Two        - 95.4
# Three      - 65.0
# Four       - 81.8
# Five       - 77.6
# Six        - 18.8
# Seven      - 48.4
# Eight      - 8.6
# Nine       - 22.1
#
# Backdoor ASR 2.81
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.298441
#
# Average test loss: 0.7416, Test accuracy: 8400/10000 (84.00%)
#
# Class      - Accuracy
# Zero       - 96.6
# One        - 98.5
# Two        - 86.5
# Three      - 82.4
# Four       - 90.0
# Five       - 76.9
# Six        - 90.0
# Seven      - 76.7
# Eight      - 56.9
# Nine       - 82.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.814268
#
# Average test loss: 0.4213, Test accuracy: 9040/10000 (90.40%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.4
# Two        - 92.4
# Three      - 89.7
# Four       - 95.1
# Five       - 89.3
# Six        - 94.5
# Seven      - 83.9
# Eight      - 74.8
# Nine       - 86.4
#
# Backdoor ASR 0.1
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.664328
#
# Average test loss: 0.3118, Test accuracy: 9208/10000 (92.08%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.7
# Two        - 92.6
# Three      - 90.5
# Four       - 96.8
# Five       - 92.2
# Six        - 95.9
# Seven      - 86.9
# Eight      - 80.5
# Nine       - 87.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.572094
#
# Average test loss: 0.2562, Test accuracy: 9313/10000 (93.13%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 94.4
# Three      - 93.1
# Four       - 96.4
# Five       - 92.7
# Six        - 96.6
# Seven      - 86.4
# Eight      - 83.2
# Nine       - 90.7
#
# Backdoor ASR 0.1
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.532162
#
# Average test loss: 0.2225, Test accuracy: 9386/10000 (93.86%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 93.9
# Three      - 93.4
# Four       - 96.5
# Five       - 94.5
# Six        - 96.9
# Seven      - 86.4
# Eight      - 86.9
# Nine       - 92.6
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.484250
#
# Average test loss: 0.1932, Test accuracy: 9454/10000 (94.54%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.9
# Two        - 94.2
# Three      - 93.5
# Four       - 97.3
# Five       - 95.3
# Six        - 97.7
# Seven      - 88.0
# Eight      - 89.9
# Nine       - 92.6
#
# Backdoor ASR 0.19
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.457576
#
# Average test loss: 0.1770, Test accuracy: 9497/10000 (94.97%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 94.7
# Three      - 94.4
# Four       - 96.7
# Five       - 96.2
# Six        - 97.4
# Seven      - 90.8
# Eight      - 88.4
# Nine       - 93.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.430636
#
# Average test loss: 0.1628, Test accuracy: 9531/10000 (95.31%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.6
# Three      - 94.2
# Four       - 97.1
# Five       - 96.7
# Six        - 97.6
# Seven      - 90.5
# Eight      - 89.9
# Nine       - 93.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.414452
#
# Average test loss: 0.1523, Test accuracy: 9551/10000 (95.51%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 95.5
# Three      - 95.6
# Four       - 97.0
# Five       - 97.1
# Six        - 97.8
# Seven      - 90.0
# Eight      - 89.9
# Nine       - 94.5
#
# Backdoor ASR 0.19
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.395091
#
# Average test loss: 0.1400, Test accuracy: 9578/10000 (95.78%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 95.7
# Three      - 95.5
# Four       - 97.3
# Five       - 96.9
# Six        - 97.8
# Seven      - 90.8
# Eight      - 91.5
# Nine       - 94.7
#
# Backdoor ASR 0.1
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.385889
#
# Average test loss: 0.1324, Test accuracy: 9603/10000 (96.03%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 96.1
# Three      - 95.7
# Four       - 97.1
# Five       - 97.9
# Six        - 97.7
# Seven      - 91.6
# Eight      - 91.7
# Nine       - 94.7
#
# Backdoor ASR 0.1
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.363176
#
# Average test loss: 0.1240, Test accuracy: 9616/10000 (96.16%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 96.9
# Three      - 96.2
# Four       - 96.9
# Five       - 97.3
# Six        - 97.7
# Seven      - 91.4
# Eight      - 92.1
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.356512
#
# Average test loss: 0.1185, Test accuracy: 9655/10000 (96.55%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.8
# Three      - 96.5
# Four       - 97.3
# Five       - 98.2
# Six        - 97.8
# Seven      - 93.3
# Eight      - 92.9
# Nine       - 95.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.352016
#
# Average test loss: 0.1143, Test accuracy: 9656/10000 (96.56%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 96.7
# Three      - 96.7
# Four       - 97.3
# Five       - 98.2
# Six        - 98.1
# Seven      - 92.0
# Eight      - 93.9
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.338663
#
# Average test loss: 0.1080, Test accuracy: 9669/10000 (96.69%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 97.3
# Three      - 96.5
# Four       - 97.4
# Five       - 98.3
# Six        - 97.8
# Seven      - 92.3
# Eight      - 94.3
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.340940
#
# Average test loss: 0.1073, Test accuracy: 9678/10000 (96.78%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 97.2
# Three      - 97.2
# Four       - 97.7
# Five       - 98.5
# Six        - 97.7
# Seven      - 92.4
# Eight      - 93.6
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.325837
#
# Average test loss: 0.1014, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.2
# Three      - 97.4
# Four       - 97.8
# Five       - 98.5
# Six        - 97.8
# Seven      - 94.0
# Eight      - 93.5
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.320927
#
# Average test loss: 0.0982, Test accuracy: 9702/10000 (97.02%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.4
# Three      - 97.1
# Four       - 97.6
# Five       - 98.7
# Six        - 97.7
# Seven      - 93.9
# Eight      - 94.0
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.310296
#
# Average test loss: 0.0963, Test accuracy: 9712/10000 (97.12%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.0
# Two        - 97.4
# Three      - 97.0
# Four       - 97.5
# Five       - 98.5
# Six        - 98.2
# Seven      - 93.8
# Eight      - 94.7
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.312658
#
# Average test loss: 0.0943, Test accuracy: 9723/10000 (97.23%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.6
# Three      - 97.3
# Four       - 97.8
# Five       - 98.8
# Six        - 98.3
# Seven      - 93.5
# Eight      - 95.1
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.307143
#
# Average test loss: 0.0913, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 97.6
# Three      - 97.3
# Four       - 97.1
# Five       - 98.9
# Six        - 97.9
# Seven      - 93.7
# Eight      - 95.3
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.300874
#
# Average test loss: 0.0883, Test accuracy: 9729/10000 (97.29%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.8
# Three      - 97.3
# Four       - 97.8
# Five       - 98.4
# Six        - 98.2
# Seven      - 93.9
# Eight      - 95.6
# Nine       - 95.8
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.295803
#
# Average test loss: 0.0876, Test accuracy: 9735/10000 (97.35%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.8
# Three      - 97.2
# Four       - 97.6
# Five       - 98.8
# Six        - 98.3
# Seven      - 94.1
# Eight      - 95.2
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.288880
#
# Average test loss: 0.0843, Test accuracy: 9739/10000 (97.39%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.8
# Three      - 97.4
# Four       - 97.4
# Five       - 98.5
# Six        - 98.2
# Seven      - 94.8
# Eight      - 95.1
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.284481
#
# Average test loss: 0.0821, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 98.9
# Two        - 98.1
# Three      - 97.3
# Four       - 97.8
# Five       - 98.8
# Six        - 98.2
# Seven      - 94.6
# Eight      - 95.1
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.285489
#
# Average test loss: 0.0808, Test accuracy: 9748/10000 (97.48%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.6
# Three      - 97.2
# Four       - 97.6
# Five       - 98.9
# Six        - 98.3
# Seven      - 95.0
# Eight      - 95.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.279611
#
# Average test loss: 0.0793, Test accuracy: 9759/10000 (97.59%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.9
# Three      - 97.5
# Four       - 98.0
# Five       - 98.8
# Six        - 98.4
# Seven      - 95.3
# Eight      - 95.6
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.275306
#
# Average test loss: 0.0781, Test accuracy: 9759/10000 (97.59%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 98.0
# Three      - 97.3
# Four       - 97.7
# Five       - 98.8
# Six        - 98.4
# Seven      - 95.0
# Eight      - 96.2
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.269095
#
# Average test loss: 0.0778, Test accuracy: 9758/10000 (97.58%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 97.9
# Three      - 97.4
# Four       - 97.7
# Five       - 98.7
# Six        - 98.4
# Seven      - 94.7
# Eight      - 96.0
# Nine       - 96.7
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0836, Test accuracy: 9741/10000 (97.41%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.8
# Three      - 97.3
# Four       - 97.6
# Five       - 98.8
# Six        - 98.3
# Seven      - 94.6
# Eight      - 95.4
# Nine       - 96.2
# Global accuracies:  [53.75, 84.0, 90.4, 92.08, 93.13, 93.86, 94.54, 94.97, 95.31, 95.51, 95.78, 96.03, 96.16, 96.55, 96.56, 96.69, 96.78, 97.0, 97.02, 97.12, 97.23, 97.19, 97.29, 97.35, 97.39, 97.41, 97.48, 97.59, 97.59, 97.58, 97.41]
# Class 2 accuracies:  [95.45, 86.53, 92.44, 92.64, 94.38, 93.9, 94.19, 94.67, 95.64, 95.54, 95.74, 96.12, 96.9, 96.8, 96.71, 97.29, 97.19, 97.19, 97.38, 97.38, 97.58, 97.58, 97.77, 97.77, 97.77, 98.06, 97.58, 97.87, 97.97, 97.87, 97.77]
# Test loss: [1.9988, 0.7416, 0.4213, 0.3118, 0.2562, 0.2225, 0.1932, 0.177, 0.1628, 0.1523, 0.14, 0.1324, 0.124, 0.1185, 0.1143, 0.108, 0.1073, 0.1014, 0.0982, 0.0963, 0.0943, 0.0913, 0.0883, 0.0876, 0.0843, 0.0821, 0.0808, 0.0793, 0.0781, 0.0778, 0.0836]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.01331489086151123
#
# --> End of Experiment.

# %%
RULE = 'mkrum'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: mkrum
# Attack Type: backdoor
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.885374
#
# Average test loss: 1.9441, Test accuracy: 5727/10000 (57.27%)
#
# Class      - Accuracy
# Zero       - 19.2
# One        - 91.0
# Two        - 93.5
# Three      - 87.2
# Four       - 86.2
# Five       - 14.5
# Six        - 61.1
# Seven      - 31.0
# Eight      - 28.0
# Nine       - 50.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.224573
#
# Average test loss: 0.6903, Test accuracy: 8353/10000 (83.53%)
#
# Class      - Accuracy
# Zero       - 97.2
# One        - 98.4
# Two        - 89.3
# Three      - 87.9
# Four       - 90.8
# Five       - 66.3
# Six        - 89.8
# Seven      - 75.5
# Eight      - 54.8
# Nine       - 81.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.754724
#
# Average test loss: 0.4023, Test accuracy: 8959/10000 (89.59%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.6
# Two        - 93.1
# Three      - 88.8
# Four       - 95.9
# Five       - 88.0
# Six        - 94.3
# Seven      - 79.1
# Eight      - 72.6
# Nine       - 86.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.595358
#
# Average test loss: 0.2995, Test accuracy: 9219/10000 (92.19%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.9
# Two        - 93.5
# Three      - 90.8
# Four       - 94.7
# Five       - 92.2
# Six        - 96.3
# Seven      - 84.3
# Eight      - 80.1
# Nine       - 92.4
#
# Backdoor ASR 0.1
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.504757
#
# Average test loss: 0.2397, Test accuracy: 9336/10000 (93.36%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 94.5
# Three      - 91.9
# Four       - 96.3
# Five       - 93.7
# Six        - 96.1
# Seven      - 85.7
# Eight      - 84.8
# Nine       - 92.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.448679
#
# Average test loss: 0.2104, Test accuracy: 9403/10000 (94.03%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 95.0
# Three      - 92.2
# Four       - 96.7
# Five       - 95.9
# Six        - 96.7
# Seven      - 88.6
# Eight      - 84.8
# Nine       - 92.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.412800
#
# Average test loss: 0.1887, Test accuracy: 9468/10000 (94.68%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.9
# Two        - 95.1
# Three      - 93.2
# Four       - 96.5
# Five       - 96.0
# Six        - 97.1
# Seven      - 88.8
# Eight      - 88.5
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.385843
#
# Average test loss: 0.1750, Test accuracy: 9475/10000 (94.75%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.8
# Three      - 94.5
# Four       - 95.9
# Five       - 96.3
# Six        - 96.9
# Seven      - 88.3
# Eight      - 87.6
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.361909
#
# Average test loss: 0.1595, Test accuracy: 9537/10000 (95.37%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.0
# Three      - 94.8
# Four       - 96.4
# Five       - 96.7
# Six        - 97.5
# Seven      - 90.5
# Eight      - 89.2
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.348934
#
# Average test loss: 0.1512, Test accuracy: 9540/10000 (95.40%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 96.7
# Three      - 94.7
# Four       - 96.3
# Five       - 97.4
# Six        - 97.3
# Seven      - 88.6
# Eight      - 89.8
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.328590
#
# Average test loss: 0.1390, Test accuracy: 9585/10000 (95.85%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 96.7
# Three      - 95.5
# Four       - 96.8
# Five       - 97.3
# Six        - 97.2
# Seven      - 91.0
# Eight      - 90.3
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.313333
#
# Average test loss: 0.1325, Test accuracy: 9584/10000 (95.84%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 96.9
# Three      - 95.3
# Four       - 96.9
# Five       - 97.8
# Six        - 97.5
# Seven      - 90.6
# Eight      - 90.3
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.293571
#
# Average test loss: 0.1226, Test accuracy: 9621/10000 (96.21%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.4
# Three      - 95.8
# Four       - 97.0
# Five       - 97.9
# Six        - 97.6
# Seven      - 92.0
# Eight      - 91.6
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.284887
#
# Average test loss: 0.1195, Test accuracy: 9637/10000 (96.37%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 96.6
# Three      - 95.9
# Four       - 96.6
# Five       - 97.6
# Six        - 97.8
# Seven      - 92.0
# Eight      - 92.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.278055
#
# Average test loss: 0.1151, Test accuracy: 9643/10000 (96.43%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 97.9
# Three      - 96.1
# Four       - 96.3
# Five       - 98.1
# Six        - 97.8
# Seven      - 91.3
# Eight      - 92.7
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.270385
#
# Average test loss: 0.1081, Test accuracy: 9670/10000 (96.70%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 98.0
# Three      - 96.0
# Four       - 97.1
# Five       - 98.2
# Six        - 98.0
# Seven      - 92.1
# Eight      - 93.4
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.261456
#
# Average test loss: 0.1035, Test accuracy: 9682/10000 (96.82%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 97.7
# Three      - 96.4
# Four       - 97.9
# Five       - 98.4
# Six        - 97.8
# Seven      - 92.5
# Eight      - 93.7
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.257946
#
# Average test loss: 0.1003, Test accuracy: 9697/10000 (96.97%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 98.0
# Three      - 96.5
# Four       - 97.3
# Five       - 98.1
# Six        - 98.1
# Seven      - 92.9
# Eight      - 94.7
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.249414
#
# Average test loss: 0.0977, Test accuracy: 9698/10000 (96.98%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 97.8
# Three      - 97.1
# Four       - 97.4
# Five       - 98.5
# Six        - 97.9
# Seven      - 93.0
# Eight      - 93.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.240615
#
# Average test loss: 0.0954, Test accuracy: 9704/10000 (97.04%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.9
# Three      - 97.0
# Four       - 97.3
# Five       - 98.3
# Six        - 98.0
# Seven      - 93.7
# Eight      - 93.6
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.238122
#
# Average test loss: 0.0960, Test accuracy: 9703/10000 (97.03%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 97.6
# Three      - 96.8
# Four       - 97.5
# Five       - 98.7
# Six        - 97.9
# Seven      - 93.2
# Eight      - 94.1
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.235133
#
# Average test loss: 0.0880, Test accuracy: 9722/10000 (97.22%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.5
# Three      - 96.9
# Four       - 97.6
# Five       - 98.4
# Six        - 98.0
# Seven      - 94.9
# Eight      - 94.4
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.232144
#
# Average test loss: 0.0917, Test accuracy: 9712/10000 (97.12%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 97.7
# Three      - 96.5
# Four       - 97.5
# Five       - 98.5
# Six        - 98.4
# Seven      - 93.8
# Eight      - 94.5
# Nine       - 96.5
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.221141
#
# Average test loss: 0.0863, Test accuracy: 9732/10000 (97.32%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.3
# Three      - 96.7
# Four       - 97.4
# Five       - 98.5
# Six        - 97.8
# Seven      - 94.5
# Eight      - 95.2
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.219091
#
# Average test loss: 0.0829, Test accuracy: 9742/10000 (97.42%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 98.2
# Three      - 97.0
# Four       - 97.8
# Five       - 98.5
# Six        - 98.1
# Seven      - 94.4
# Eight      - 95.5
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.210294
#
# Average test loss: 0.0821, Test accuracy: 9736/10000 (97.36%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 98.5
# Three      - 96.8
# Four       - 97.1
# Five       - 98.5
# Six        - 98.2
# Seven      - 94.2
# Eight      - 95.3
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.215870
#
# Average test loss: 0.0804, Test accuracy: 9751/10000 (97.51%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.2
# Three      - 97.0
# Four       - 97.5
# Five       - 98.7
# Six        - 98.0
# Seven      - 95.1
# Eight      - 95.2
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.209612
#
# Average test loss: 0.0781, Test accuracy: 9749/10000 (97.49%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.4
# Three      - 97.0
# Four       - 97.5
# Five       - 98.7
# Six        - 98.0
# Seven      - 94.5
# Eight      - 95.9
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.207333
#
# Average test loss: 0.0752, Test accuracy: 9770/10000 (97.70%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.8
# Three      - 97.4
# Four       - 98.3
# Five       - 98.7
# Six        - 98.0
# Seven      - 94.7
# Eight      - 95.9
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.201711
#
# Average test loss: 0.0768, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.5
# Two        - 98.4
# Three      - 97.3
# Four       - 98.5
# Five       - 98.5
# Six        - 98.2
# Seven      - 95.0
# Eight      - 95.3
# Nine       - 96.8
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0829, Test accuracy: 9745/10000 (97.45%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.3
# Three      - 97.0
# Four       - 97.8
# Five       - 98.5
# Six        - 98.0
# Seven      - 94.6
# Eight      - 95.2
# Nine       - 96.6
# Global accuracies:  [57.27, 83.53, 89.59, 92.19, 93.36, 94.03, 94.68, 94.75, 95.37, 95.4, 95.85, 95.84, 96.21, 96.37, 96.43, 96.7, 96.82, 96.97, 96.98, 97.04, 97.03, 97.22, 97.12, 97.32, 97.42, 97.36, 97.51, 97.49, 97.7, 97.67, 97.45]
# Class 2 accuracies:  [93.51, 89.34, 93.12, 93.51, 94.48, 94.96, 95.06, 95.83, 96.03, 96.71, 96.71, 96.9, 96.41, 96.61, 97.87, 97.97, 97.67, 97.97, 97.77, 97.87, 97.58, 97.48, 97.67, 98.26, 98.16, 98.55, 98.16, 98.45, 98.84, 98.35, 98.26]
# Test loss: [1.9441, 0.6903, 0.4023, 0.2995, 0.2397, 0.2104, 0.1887, 0.175, 0.1595, 0.1512, 0.139, 0.1325, 0.1226, 0.1195, 0.1151, 0.1081, 0.1035, 0.1003, 0.0977, 0.0954, 0.096, 0.088, 0.0917, 0.0863, 0.0829, 0.0821, 0.0804, 0.0781, 0.0752, 0.0768, 0.0829]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.007226475079854329
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: mkrum
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.892269
#
# Average test loss: 2.0066, Test accuracy: 5910/10000 (59.10%)
#
# Class      - Accuracy
# Zero       - 52.2
# One        - 85.7
# Two        - 95.2
# Three      - 76.5
# Four       - 82.1
# Five       - 53.1
# Six        - 25.5
# Seven      - 36.9
# Eight      - 31.5
# Nine       - 45.6
#
# Backdoor ASR 0.87
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.298855
#
# Average test loss: 0.7534, Test accuracy: 8363/10000 (83.63%)
#
# Class      - Accuracy
# Zero       - 96.0
# One        - 98.1
# Two        - 88.7
# Three      - 81.5
# Four       - 90.0
# Five       - 80.6
# Six        - 85.8
# Seven      - 71.2
# Eight      - 66.5
# Nine       - 75.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.806109
#
# Average test loss: 0.4284, Test accuracy: 8998/10000 (89.98%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.3
# Two        - 92.2
# Three      - 88.4
# Four       - 91.8
# Five       - 88.5
# Six        - 93.1
# Seven      - 81.9
# Eight      - 78.7
# Nine       - 87.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.632759
#
# Average test loss: 0.3247, Test accuracy: 9141/10000 (91.41%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.4
# Two        - 93.2
# Three      - 90.7
# Four       - 97.1
# Five       - 87.1
# Six        - 96.6
# Seven      - 82.5
# Eight      - 83.2
# Nine       - 86.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.545255
#
# Average test loss: 0.2605, Test accuracy: 9262/10000 (92.62%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.5
# Two        - 93.4
# Three      - 93.3
# Four       - 94.8
# Five       - 91.8
# Six        - 95.7
# Seven      - 82.9
# Eight      - 83.8
# Nine       - 93.5
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.486010
#
# Average test loss: 0.2254, Test accuracy: 9368/10000 (93.68%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.0
# Two        - 94.6
# Three      - 93.0
# Four       - 96.7
# Five       - 94.4
# Six        - 96.5
# Seven      - 84.2
# Eight      - 85.9
# Nine       - 93.9
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.448078
#
# Average test loss: 0.1969, Test accuracy: 9416/10000 (94.16%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 94.6
# Three      - 93.2
# Four       - 95.7
# Five       - 95.3
# Six        - 96.7
# Seven      - 86.3
# Eight      - 88.3
# Nine       - 94.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.414761
#
# Average test loss: 0.1808, Test accuracy: 9461/10000 (94.61%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 95.3
# Three      - 94.4
# Four       - 96.0
# Five       - 95.6
# Six        - 97.1
# Seven      - 86.4
# Eight      - 89.1
# Nine       - 94.8
#
# Backdoor ASR 0.1
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.391162
#
# Average test loss: 0.1702, Test accuracy: 9507/10000 (95.07%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 96.5
# Three      - 94.4
# Four       - 97.1
# Five       - 96.6
# Six        - 97.5
# Seven      - 88.0
# Eight      - 88.6
# Nine       - 94.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.368157
#
# Average test loss: 0.1523, Test accuracy: 9544/10000 (95.44%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 96.2
# Three      - 95.3
# Four       - 96.9
# Five       - 97.1
# Six        - 97.6
# Seven      - 88.4
# Eight      - 90.2
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.351223
#
# Average test loss: 0.1416, Test accuracy: 9573/10000 (95.73%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 96.2
# Three      - 95.7
# Four       - 96.8
# Five       - 97.3
# Six        - 97.5
# Seven      - 90.3
# Eight      - 90.5
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.335618
#
# Average test loss: 0.1359, Test accuracy: 9573/10000 (95.73%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 96.6
# Three      - 95.2
# Four       - 96.7
# Five       - 98.1
# Six        - 97.2
# Seven      - 89.0
# Eight      - 91.5
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.332280
#
# Average test loss: 0.1320, Test accuracy: 9585/10000 (95.85%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 97.4
# Three      - 96.0
# Four       - 96.7
# Five       - 97.8
# Six        - 97.5
# Seven      - 87.9
# Eight      - 92.0
# Nine       - 95.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.316391
#
# Average test loss: 0.1220, Test accuracy: 9623/10000 (96.23%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 97.5
# Three      - 95.8
# Four       - 97.3
# Five       - 97.9
# Six        - 97.5
# Seven      - 90.9
# Eight      - 91.7
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.310732
#
# Average test loss: 0.1195, Test accuracy: 9641/10000 (96.41%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.1
# Two        - 97.5
# Three      - 96.4
# Four       - 97.3
# Five       - 98.3
# Six        - 97.6
# Seven      - 91.1
# Eight      - 91.9
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.297829
#
# Average test loss: 0.1125, Test accuracy: 9651/10000 (96.51%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 97.8
# Three      - 96.3
# Four       - 96.6
# Five       - 98.4
# Six        - 97.2
# Seven      - 91.8
# Eight      - 92.8
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.285786
#
# Average test loss: 0.1059, Test accuracy: 9671/10000 (96.71%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 97.7
# Three      - 96.6
# Four       - 96.9
# Five       - 98.3
# Six        - 97.3
# Seven      - 93.2
# Eight      - 92.6
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.288717
#
# Average test loss: 0.1024, Test accuracy: 9677/10000 (96.77%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 97.9
# Three      - 97.0
# Four       - 96.6
# Five       - 98.2
# Six        - 97.8
# Seven      - 92.5
# Eight      - 93.2
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.276596
#
# Average test loss: 0.1009, Test accuracy: 9683/10000 (96.83%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.1
# Three      - 96.6
# Four       - 96.9
# Five       - 98.4
# Six        - 97.7
# Seven      - 92.8
# Eight      - 92.9
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.271686
#
# Average test loss: 0.0996, Test accuracy: 9694/10000 (96.94%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.1
# Three      - 97.1
# Four       - 96.5
# Five       - 98.5
# Six        - 97.7
# Seven      - 93.1
# Eight      - 93.5
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.272426
#
# Average test loss: 0.0926, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.5
# Two        - 98.1
# Three      - 96.9
# Four       - 97.1
# Five       - 98.4
# Six        - 97.7
# Seven      - 93.2
# Eight      - 94.7
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.264086
#
# Average test loss: 0.0925, Test accuracy: 9706/10000 (97.06%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.5
# Two        - 98.0
# Three      - 97.0
# Four       - 96.7
# Five       - 98.7
# Six        - 97.8
# Seven      - 93.1
# Eight      - 94.3
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.261612
#
# Average test loss: 0.0900, Test accuracy: 9714/10000 (97.14%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.2
# Three      - 97.3
# Four       - 97.4
# Five       - 98.9
# Six        - 97.6
# Seven      - 93.6
# Eight      - 93.8
# Nine       - 96.4
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.255025
#
# Average test loss: 0.0853, Test accuracy: 9745/10000 (97.45%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.5
# Two        - 98.1
# Three      - 97.2
# Four       - 97.9
# Five       - 98.8
# Six        - 97.8
# Seven      - 94.4
# Eight      - 95.3
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.247118
#
# Average test loss: 0.0854, Test accuracy: 9729/10000 (97.29%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.2
# Two        - 98.3
# Three      - 97.1
# Four       - 97.1
# Five       - 98.4
# Six        - 98.1
# Seven      - 93.9
# Eight      - 95.0
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.244919
#
# Average test loss: 0.0848, Test accuracy: 9736/10000 (97.36%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 98.3
# Three      - 97.5
# Four       - 97.3
# Five       - 98.7
# Six        - 97.8
# Seven      - 94.6
# Eight      - 94.3
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.243264
#
# Average test loss: 0.0822, Test accuracy: 9740/10000 (97.40%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 98.4
# Three      - 97.0
# Four       - 97.7
# Five       - 98.7
# Six        - 97.8
# Seven      - 94.9
# Eight      - 94.3
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.240043
#
# Average test loss: 0.0815, Test accuracy: 9746/10000 (97.46%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 98.3
# Three      - 97.4
# Four       - 97.8
# Five       - 98.7
# Six        - 98.3
# Seven      - 94.6
# Eight      - 94.7
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.240744
#
# Average test loss: 0.0796, Test accuracy: 9757/10000 (97.57%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 98.8
# Three      - 97.2
# Four       - 97.4
# Five       - 98.9
# Six        - 98.2
# Seven      - 94.5
# Eight      - 95.3
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.237544
#
# Average test loss: 0.0755, Test accuracy: 9772/10000 (97.72%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 98.7
# Three      - 97.7
# Four       - 98.1
# Five       - 98.7
# Six        - 97.9
# Seven      - 95.1
# Eight      - 95.7
# Nine       - 96.8
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0841, Test accuracy: 9741/10000 (97.41%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 98.3
# Three      - 97.2
# Four       - 97.8
# Five       - 98.7
# Six        - 98.0
# Seven      - 94.4
# Eight      - 94.8
# Nine       - 96.6
# Global accuracies:  [59.1, 83.63, 89.98, 91.41, 92.62, 93.68, 94.16, 94.61, 95.07, 95.44, 95.73, 95.73, 95.85, 96.23, 96.41, 96.51, 96.71, 96.77, 96.83, 96.94, 97.09, 97.06, 97.14, 97.45, 97.29, 97.36, 97.4, 97.46, 97.57, 97.72, 97.41]
# Class 2 accuracies:  [95.16, 88.66, 92.25, 93.22, 93.41, 94.57, 94.57, 95.35, 96.51, 96.22, 96.22, 96.61, 97.38, 97.48, 97.48, 97.77, 97.67, 97.87, 98.06, 98.06, 98.06, 97.97, 98.16, 98.06, 98.26, 98.26, 98.45, 98.26, 98.84, 98.74, 98.26]
# Test loss: [2.0066, 0.7534, 0.4284, 0.3247, 0.2605, 0.2254, 0.1969, 0.1808, 0.1702, 0.1523, 0.1416, 0.1359, 0.132, 0.122, 0.1195, 0.1125, 0.1059, 0.1024, 0.1009, 0.0996, 0.0926, 0.0925, 0.09, 0.0853, 0.0854, 0.0848, 0.0822, 0.0815, 0.0796, 0.0755, 0.0841]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.006998308499654134
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: mkrum
# Attack Type: backdoor
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.893855
#
# Average test loss: 2.0529, Test accuracy: 3657/10000 (36.57%)
#
# Class      - Accuracy
# Zero       - 0.7
# One        - 1.1
# Two        - 98.0
# Three      - 47.3
# Four       - 86.4
# Five       - 59.4
# Six        - 0.0
# Seven      - 40.7
# Eight      - 7.0
# Nine       - 28.1
#
# Backdoor ASR 0.97
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.347816
#
# Average test loss: 0.8489, Test accuracy: 8403/10000 (84.03%)
#
# Class      - Accuracy
# Zero       - 96.1
# One        - 97.2
# Two        - 93.0
# Three      - 82.1
# Four       - 88.5
# Five       - 79.5
# Six        - 80.3
# Seven      - 71.3
# Eight      - 68.1
# Nine       - 81.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.849876
#
# Average test loss: 0.4755, Test accuracy: 8924/10000 (89.24%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 97.8
# Two        - 93.8
# Three      - 86.4
# Four       - 92.7
# Five       - 89.1
# Six        - 92.1
# Seven      - 79.6
# Eight      - 76.7
# Nine       - 85.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.685862
#
# Average test loss: 0.3280, Test accuracy: 9172/10000 (91.72%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.8
# Two        - 92.7
# Three      - 91.1
# Four       - 96.1
# Five       - 87.0
# Six        - 95.7
# Seven      - 86.2
# Eight      - 83.3
# Nine       - 87.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.587561
#
# Average test loss: 0.2857, Test accuracy: 9261/10000 (92.61%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.5
# Two        - 93.9
# Three      - 90.0
# Four       - 96.6
# Five       - 91.3
# Six        - 96.3
# Seven      - 85.0
# Eight      - 85.6
# Nine       - 90.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.542046
#
# Average test loss: 0.2395, Test accuracy: 9360/10000 (93.60%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.9
# Two        - 93.9
# Three      - 93.3
# Four       - 96.6
# Five       - 92.4
# Six        - 96.5
# Seven      - 86.1
# Eight      - 88.0
# Nine       - 91.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.491425
#
# Average test loss: 0.2034, Test accuracy: 9418/10000 (94.18%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.5
# Two        - 94.0
# Three      - 93.0
# Four       - 97.5
# Five       - 92.9
# Six        - 97.3
# Seven      - 88.4
# Eight      - 90.3
# Nine       - 91.7
#
# Backdoor ASR 0.19
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.462017
#
# Average test loss: 0.1909, Test accuracy: 9459/10000 (94.59%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.0
# Two        - 94.4
# Three      - 93.8
# Four       - 96.6
# Five       - 95.9
# Six        - 97.0
# Seven      - 90.1
# Eight      - 87.4
# Nine       - 93.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.436566
#
# Average test loss: 0.1721, Test accuracy: 9527/10000 (95.27%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 98.7
# Two        - 96.2
# Three      - 93.8
# Four       - 97.0
# Five       - 96.2
# Six        - 97.3
# Seven      - 90.3
# Eight      - 91.0
# Nine       - 94.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.415670
#
# Average test loss: 0.1552, Test accuracy: 9560/10000 (95.60%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 96.2
# Three      - 95.5
# Four       - 96.8
# Five       - 97.0
# Six        - 97.3
# Seven      - 90.7
# Eight      - 90.7
# Nine       - 94.2
#
# Backdoor ASR 0.19
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.396409
#
# Average test loss: 0.1449, Test accuracy: 9584/10000 (95.84%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 96.4
# Three      - 95.5
# Four       - 97.0
# Five       - 96.2
# Six        - 97.5
# Seven      - 90.9
# Eight      - 92.8
# Nine       - 94.4
#
# Backdoor ASR 0.1
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.384759
#
# Average test loss: 0.1373, Test accuracy: 9609/10000 (96.09%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.9
# Three      - 95.3
# Four       - 96.9
# Five       - 97.2
# Six        - 97.6
# Seven      - 91.6
# Eight      - 93.0
# Nine       - 94.6
#
# Backdoor ASR 0.1
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.363437
#
# Average test loss: 0.1317, Test accuracy: 9600/10000 (96.00%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 96.6
# Three      - 95.7
# Four       - 96.4
# Five       - 97.0
# Six        - 97.6
# Seven      - 91.1
# Eight      - 92.7
# Nine       - 95.1
#
# Backdoor ASR 0.1
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.353541
#
# Average test loss: 0.1246, Test accuracy: 9634/10000 (96.34%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 96.4
# Three      - 96.0
# Four       - 97.0
# Five       - 97.1
# Six        - 97.7
# Seven      - 92.4
# Eight      - 93.5
# Nine       - 95.2
#
# Backdoor ASR 0.1
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.346124
#
# Average test loss: 0.1215, Test accuracy: 9645/10000 (96.45%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.8
# Two        - 97.0
# Three      - 96.3
# Four       - 97.4
# Five       - 97.9
# Six        - 97.9
# Seven      - 91.3
# Eight      - 94.4
# Nine       - 95.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.333218
#
# Average test loss: 0.1147, Test accuracy: 9650/10000 (96.50%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 97.7
# Three      - 96.3
# Four       - 97.1
# Five       - 97.5
# Six        - 97.7
# Seven      - 91.6
# Eight      - 94.1
# Nine       - 95.1
#
# Backdoor ASR 0.1
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.332918
#
# Average test loss: 0.1118, Test accuracy: 9678/10000 (96.78%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 97.3
# Three      - 96.8
# Four       - 97.3
# Five       - 98.5
# Six        - 97.9
# Seven      - 92.7
# Eight      - 94.0
# Nine       - 95.8
#
# Backdoor ASR 0.1
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.317818
#
# Average test loss: 0.1067, Test accuracy: 9680/10000 (96.80%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.3
# Three      - 96.0
# Four       - 97.7
# Five       - 98.5
# Six        - 97.6
# Seven      - 93.7
# Eight      - 93.7
# Nine       - 95.7
#
# Backdoor ASR 0.1
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.312206
#
# Average test loss: 0.1042, Test accuracy: 9685/10000 (96.85%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.0
# Two        - 97.4
# Three      - 96.9
# Four       - 97.6
# Five       - 98.5
# Six        - 97.7
# Seven      - 93.0
# Eight      - 93.9
# Nine       - 95.7
#
# Backdoor ASR 0.1
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.302518
#
# Average test loss: 0.1019, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 98.0
# Three      - 96.3
# Four       - 97.6
# Five       - 98.5
# Six        - 97.8
# Seven      - 93.5
# Eight      - 94.8
# Nine       - 95.8
#
# Backdoor ASR 0.1
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.300510
#
# Average test loss: 0.1018, Test accuracy: 9695/10000 (96.95%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 98.5
# Three      - 96.4
# Four       - 97.6
# Five       - 98.4
# Six        - 97.5
# Seven      - 91.6
# Eight      - 95.7
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.299945
#
# Average test loss: 0.0941, Test accuracy: 9715/10000 (97.15%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 97.8
# Three      - 97.0
# Four       - 97.5
# Five       - 98.5
# Six        - 98.0
# Seven      - 93.9
# Eight      - 95.2
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.293285
#
# Average test loss: 0.0917, Test accuracy: 9721/10000 (97.21%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.3
# Two        - 97.8
# Three      - 97.0
# Four       - 97.9
# Five       - 98.4
# Six        - 97.8
# Seven      - 93.7
# Eight      - 95.2
# Nine       - 96.0
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.288851
#
# Average test loss: 0.0918, Test accuracy: 9729/10000 (97.29%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.6
# Two        - 97.8
# Three      - 97.1
# Four       - 97.9
# Five       - 98.3
# Six        - 98.1
# Seven      - 93.9
# Eight      - 95.3
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.279935
#
# Average test loss: 0.0867, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 98.2
# Three      - 97.7
# Four       - 97.9
# Five       - 98.4
# Six        - 97.9
# Seven      - 93.9
# Eight      - 95.6
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.274905
#
# Average test loss: 0.0903, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.1
# Two        - 98.6
# Three      - 96.9
# Four       - 98.2
# Five       - 98.7
# Six        - 97.8
# Seven      - 92.7
# Eight      - 95.5
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.272375
#
# Average test loss: 0.0835, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 98.2
# Three      - 97.3
# Four       - 98.3
# Five       - 98.7
# Six        - 98.2
# Seven      - 94.4
# Eight      - 96.4
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.269771
#
# Average test loss: 0.0863, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 98.3
# Three      - 97.4
# Four       - 98.2
# Five       - 98.7
# Six        - 97.9
# Seven      - 94.2
# Eight      - 95.1
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.260763
#
# Average test loss: 0.0851, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.2
# Two        - 98.6
# Three      - 97.5
# Four       - 98.7
# Five       - 98.7
# Six        - 97.7
# Seven      - 94.0
# Eight      - 95.5
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.257160
#
# Average test loss: 0.0827, Test accuracy: 9740/10000 (97.40%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 98.5
# Three      - 97.2
# Four       - 98.1
# Five       - 98.7
# Six        - 98.1
# Seven      - 93.9
# Eight      - 95.0
# Nine       - 96.4
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0880, Test accuracy: 9728/10000 (97.28%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 98.2
# Three      - 97.0
# Four       - 97.8
# Five       - 98.7
# Six        - 97.9
# Seven      - 93.7
# Eight      - 95.3
# Nine       - 96.3
# Global accuracies:  [36.57, 84.03, 89.24, 91.72, 92.61, 93.6, 94.18, 94.59, 95.27, 95.6, 95.84, 96.09, 96.0, 96.34, 96.45, 96.5, 96.78, 96.8, 96.85, 97.0, 96.95, 97.15, 97.21, 97.29, 97.41, 97.27, 97.56, 97.44, 97.53, 97.4, 97.28]
# Class 2 accuracies:  [97.97, 93.02, 93.8, 92.73, 93.9, 93.9, 93.99, 94.38, 96.22, 96.22, 96.41, 96.9, 96.61, 96.41, 97.0, 97.67, 97.29, 97.29, 97.38, 97.97, 98.55, 97.77, 97.77, 97.77, 98.16, 98.64, 98.16, 98.26, 98.64, 98.55, 98.16]
# Test loss: [2.0529, 0.8489, 0.4755, 0.328, 0.2857, 0.2395, 0.2034, 0.1909, 0.1721, 0.1552, 0.1449, 0.1373, 0.1317, 0.1246, 0.1215, 0.1147, 0.1118, 0.1067, 0.1042, 0.1019, 0.1018, 0.0941, 0.0917, 0.0918, 0.0867, 0.0903, 0.0835, 0.0863, 0.0851, 0.0827, 0.088]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.006898776690165202
#
# --> End of Experiment.

# %%
RULE = 'foolsgold'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type = ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: foolsgold
# Attack Type: backdoor
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.885302
#
# Average test loss: 1.8097, Test accuracy: 6469/10000 (64.69%)
#
# Class      - Accuracy
# Zero       - 70.5
# One        - 98.1
# Two        - 79.7
# Three      - 91.9
# Four       - 87.4
# Five       - 1.1
# Six        - 83.7
# Seven      - 82.9
# Eight      - 3.7
# Nine       - 35.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.150337
#
# Average test loss: 0.6627, Test accuracy: 8073/10000 (80.73%)
#
# Class      - Accuracy
# Zero       - 95.4
# One        - 98.4
# Two        - 87.4
# Three      - 89.3
# Four       - 91.1
# Five       - 35.9
# Six        - 94.4
# Seven      - 90.0
# Eight      - 35.5
# Nine       - 82.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.724597
#
# Average test loss: 0.4036, Test accuracy: 8926/10000 (89.26%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.8
# Two        - 92.1
# Three      - 91.4
# Four       - 96.6
# Five       - 78.7
# Six        - 96.6
# Seven      - 90.4
# Eight      - 61.5
# Nine       - 86.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.573865
#
# Average test loss: 0.3003, Test accuracy: 9202/10000 (92.02%)
#
# Class      - Accuracy
# Zero       - 96.6
# One        - 98.9
# Two        - 93.0
# Three      - 93.2
# Four       - 95.8
# Five       - 88.9
# Six        - 97.7
# Seven      - 91.3
# Eight      - 71.7
# Nine       - 91.6
#
# Backdoor ASR 0.1
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.490042
#
# Average test loss: 0.2378, Test accuracy: 9336/10000 (93.36%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 99.0
# Two        - 93.5
# Three      - 92.9
# Four       - 96.6
# Five       - 90.9
# Six        - 97.5
# Seven      - 91.6
# Eight      - 79.9
# Nine       - 92.9
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.434754
#
# Average test loss: 0.2108, Test accuracy: 9395/10000 (93.95%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.0
# Two        - 94.4
# Three      - 93.3
# Four       - 96.6
# Five       - 93.9
# Six        - 97.5
# Seven      - 92.5
# Eight      - 80.4
# Nine       - 93.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.402948
#
# Average test loss: 0.1896, Test accuracy: 9450/10000 (94.50%)
#
# Class      - Accuracy
# Zero       - 97.7
# One        - 98.9
# Two        - 94.8
# Three      - 94.4
# Four       - 96.6
# Five       - 94.1
# Six        - 97.8
# Seven      - 92.9
# Eight      - 83.0
# Nine       - 94.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.376578
#
# Average test loss: 0.1745, Test accuracy: 9477/10000 (94.77%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 99.0
# Two        - 95.5
# Three      - 94.9
# Four       - 96.4
# Five       - 95.3
# Six        - 97.9
# Seven      - 92.9
# Eight      - 82.5
# Nine       - 94.6
#
# Backdoor ASR 0.1
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.351961
#
# Average test loss: 0.1603, Test accuracy: 9545/10000 (95.45%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 95.5
# Three      - 95.1
# Four       - 96.5
# Five       - 94.6
# Six        - 97.9
# Seven      - 94.9
# Eight      - 86.7
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.340100
#
# Average test loss: 0.1508, Test accuracy: 9548/10000 (95.48%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 96.0
# Three      - 95.7
# Four       - 96.4
# Five       - 95.7
# Six        - 98.0
# Seven      - 92.9
# Eight      - 86.0
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.319510
#
# Average test loss: 0.1416, Test accuracy: 9578/10000 (95.78%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 96.5
# Three      - 95.9
# Four       - 96.8
# Five       - 96.3
# Six        - 97.9
# Seven      - 94.1
# Eight      - 86.9
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.304988
#
# Average test loss: 0.1333, Test accuracy: 9605/10000 (96.05%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 96.1
# Three      - 96.4
# Four       - 96.8
# Five       - 96.6
# Six        - 98.1
# Seven      - 94.6
# Eight      - 88.0
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.287264
#
# Average test loss: 0.1246, Test accuracy: 9636/10000 (96.36%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.4
# Two        - 96.3
# Three      - 95.9
# Four       - 97.4
# Five       - 97.1
# Six        - 98.3
# Seven      - 95.6
# Eight      - 89.3
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.280016
#
# Average test loss: 0.1217, Test accuracy: 9625/10000 (96.25%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.2
# Two        - 96.0
# Three      - 96.0
# Four       - 96.8
# Five       - 96.6
# Six        - 98.0
# Seven      - 95.4
# Eight      - 89.3
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.272724
#
# Average test loss: 0.1137, Test accuracy: 9659/10000 (96.59%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 97.0
# Three      - 96.6
# Four       - 96.6
# Five       - 97.2
# Six        - 98.5
# Seven      - 95.1
# Eight      - 90.8
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.263529
#
# Average test loss: 0.1086, Test accuracy: 9685/10000 (96.85%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 99.3
# Two        - 97.3
# Three      - 96.6
# Four       - 97.3
# Five       - 97.6
# Six        - 98.5
# Seven      - 95.6
# Eight      - 91.2
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.255917
#
# Average test loss: 0.1034, Test accuracy: 9696/10000 (96.96%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.6
# Two        - 97.1
# Three      - 96.7
# Four       - 97.9
# Five       - 97.6
# Six        - 98.5
# Seven      - 95.4
# Eight      - 92.3
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.252659
#
# Average test loss: 0.0999, Test accuracy: 9714/10000 (97.14%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.4
# Two        - 97.8
# Three      - 97.1
# Four       - 97.3
# Five       - 97.8
# Six        - 98.6
# Seven      - 95.6
# Eight      - 92.6
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.244274
#
# Average test loss: 0.0992, Test accuracy: 9687/10000 (96.87%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 97.5
# Three      - 96.8
# Four       - 96.8
# Five       - 97.5
# Six        - 98.1
# Seven      - 95.8
# Eight      - 91.7
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.235598
#
# Average test loss: 0.0945, Test accuracy: 9710/10000 (97.10%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.4
# Two        - 97.6
# Three      - 97.3
# Four       - 97.3
# Five       - 97.5
# Six        - 98.3
# Seven      - 96.6
# Eight      - 91.8
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.232228
#
# Average test loss: 0.0916, Test accuracy: 9722/10000 (97.22%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.4
# Two        - 97.5
# Three      - 97.0
# Four       - 97.6
# Five       - 98.0
# Six        - 98.4
# Seven      - 96.2
# Eight      - 93.0
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.230452
#
# Average test loss: 0.0890, Test accuracy: 9732/10000 (97.32%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.3
# Two        - 97.5
# Three      - 97.4
# Four       - 97.5
# Five       - 97.6
# Six        - 98.1
# Seven      - 96.8
# Eight      - 93.4
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.230086
#
# Average test loss: 0.0880, Test accuracy: 9722/10000 (97.22%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.2
# Two        - 97.7
# Three      - 97.0
# Four       - 98.0
# Five       - 97.8
# Six        - 98.7
# Seven      - 95.7
# Eight      - 93.2
# Nine       - 96.3
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.215551
#
# Average test loss: 0.0847, Test accuracy: 9745/10000 (97.45%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.5
# Two        - 97.8
# Three      - 97.5
# Four       - 98.1
# Five       - 97.9
# Six        - 98.3
# Seven      - 96.4
# Eight      - 93.6
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.214755
#
# Average test loss: 0.0822, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.3
# Two        - 97.8
# Three      - 97.6
# Four       - 97.7
# Five       - 97.9
# Six        - 98.3
# Seven      - 96.1
# Eight      - 94.0
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.209158
#
# Average test loss: 0.0799, Test accuracy: 9750/10000 (97.50%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.4
# Two        - 98.1
# Three      - 97.3
# Four       - 96.9
# Five       - 98.0
# Six        - 98.9
# Seven      - 96.6
# Eight      - 94.4
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.211376
#
# Average test loss: 0.0800, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.7
# Three      - 97.7
# Four       - 97.4
# Five       - 98.1
# Six        - 98.5
# Seven      - 96.7
# Eight      - 94.1
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.205615
#
# Average test loss: 0.0767, Test accuracy: 9758/10000 (97.58%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 98.2
# Three      - 97.7
# Four       - 97.4
# Five       - 98.1
# Six        - 98.4
# Seven      - 96.2
# Eight      - 94.4
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.206186
#
# Average test loss: 0.0763, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 98.4
# Three      - 97.6
# Four       - 97.8
# Five       - 97.8
# Six        - 98.5
# Seven      - 96.7
# Eight      - 94.5
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.199628
#
# Average test loss: 0.0776, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.6
# Two        - 98.1
# Three      - 97.8
# Four       - 98.4
# Five       - 97.8
# Six        - 98.6
# Seven      - 96.4
# Eight      - 93.8
# Nine       - 96.9
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0815, Test accuracy: 9745/10000 (97.45%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.4
# Two        - 97.8
# Three      - 97.5
# Four       - 97.8
# Five       - 97.8
# Six        - 98.4
# Seven      - 96.3
# Eight      - 93.8
# Nine       - 96.8
# Global accuracies:  [64.69, 80.73, 89.26, 92.02, 93.36, 93.95, 94.5, 94.77, 95.45, 95.48, 95.78, 96.05, 96.36, 96.25, 96.59, 96.85, 96.96, 97.14, 96.87, 97.1, 97.22, 97.32, 97.22, 97.45, 97.44, 97.5, 97.56, 97.58, 97.67, 97.68, 97.45]
# Class 2 accuracies:  [79.75, 87.4, 92.05, 93.02, 93.51, 94.38, 94.77, 95.54, 95.54, 96.03, 96.51, 96.12, 96.32, 96.03, 97.0, 97.29, 97.09, 97.77, 97.48, 97.58, 97.48, 97.48, 97.67, 97.77, 97.77, 98.06, 97.67, 98.16, 98.45, 98.06, 97.77]
# Test loss: [1.8097, 0.6627, 0.4036, 0.3003, 0.2378, 0.2108, 0.1896, 0.1745, 0.1603, 0.1508, 0.1416, 0.1333, 0.1246, 0.1217, 0.1137, 0.1086, 0.1034, 0.0999, 0.0992, 0.0945, 0.0916, 0.089, 0.088, 0.0847, 0.0822, 0.0799, 0.08, 0.0767, 0.0763, 0.0776, 0.0815]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.01183012326558431
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: foolsgold
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.892198
#
# Average test loss: 1.8217, Test accuracy: 6522/10000 (65.22%)
#
# Class      - Accuracy
# Zero       - 64.1
# One        - 98.0
# Two        - 79.6
# Three      - 92.9
# Four       - 86.9
# Five       - 4.4
# Six        - 83.1
# Seven      - 82.6
# Eight      - 5.4
# Nine       - 42.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.165342
#
# Average test loss: 0.6624, Test accuracy: 8139/10000 (81.39%)
#
# Class      - Accuracy
# Zero       - 94.4
# One        - 98.6
# Two        - 86.5
# Three      - 87.9
# Four       - 90.6
# Five       - 44.1
# Six        - 95.2
# Seven      - 87.7
# Eight      - 37.3
# Nine       - 84.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.741455
#
# Average test loss: 0.4338, Test accuracy: 8831/10000 (88.31%)
#
# Class      - Accuracy
# Zero       - 97.0
# One        - 98.8
# Two        - 91.2
# Three      - 92.4
# Four       - 93.3
# Five       - 72.8
# Six        - 97.6
# Seven      - 90.0
# Eight      - 57.1
# Nine       - 89.6
#
# Backdoor ASR 0.1
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.595153
#
# Average test loss: 0.3209, Test accuracy: 9140/10000 (91.40%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.9
# Two        - 91.4
# Three      - 92.8
# Four       - 96.2
# Five       - 83.6
# Six        - 97.8
# Seven      - 91.2
# Eight      - 72.3
# Nine       - 90.1
#
# Backdoor ASR 0.1
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.518639
#
# Average test loss: 0.2687, Test accuracy: 9263/10000 (92.63%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.0
# Two        - 92.2
# Three      - 94.3
# Four       - 95.1
# Five       - 88.3
# Six        - 97.4
# Seven      - 91.5
# Eight      - 75.3
# Nine       - 93.7
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.462929
#
# Average test loss: 0.2261, Test accuracy: 9363/10000 (93.63%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.0
# Two        - 93.7
# Three      - 94.4
# Four       - 96.7
# Five       - 91.4
# Six        - 97.8
# Seven      - 90.7
# Eight      - 79.9
# Nine       - 93.8
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.429331
#
# Average test loss: 0.1946, Test accuracy: 9454/10000 (94.54%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 94.3
# Three      - 95.7
# Four       - 96.0
# Five       - 92.8
# Six        - 97.8
# Seven      - 92.0
# Eight      - 85.0
# Nine       - 93.8
#
# Backdoor ASR 0.1
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.398971
#
# Average test loss: 0.1829, Test accuracy: 9470/10000 (94.70%)
#
# Class      - Accuracy
# Zero       - 98.2
# One        - 99.0
# Two        - 94.6
# Three      - 94.4
# Four       - 96.1
# Five       - 93.4
# Six        - 97.9
# Seven      - 92.6
# Eight      - 85.2
# Nine       - 94.9
#
# Backdoor ASR 0.19
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.378883
#
# Average test loss: 0.1689, Test accuracy: 9515/10000 (95.15%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 99.0
# Two        - 95.4
# Three      - 95.3
# Four       - 96.8
# Five       - 94.8
# Six        - 98.0
# Seven      - 93.0
# Eight      - 85.4
# Nine       - 94.9
#
# Backdoor ASR 0.19
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.356137
#
# Average test loss: 0.1583, Test accuracy: 9548/10000 (95.48%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.0
# Two        - 95.3
# Three      - 96.1
# Four       - 96.5
# Five       - 95.2
# Six        - 98.1
# Seven      - 94.1
# Eight      - 86.2
# Nine       - 95.3
#
# Backdoor ASR 0.19
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.342593
#
# Average test loss: 0.1453, Test accuracy: 9577/10000 (95.77%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 96.2
# Three      - 96.7
# Four       - 96.0
# Five       - 95.0
# Six        - 97.9
# Seven      - 94.0
# Eight      - 88.5
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.326041
#
# Average test loss: 0.1356, Test accuracy: 9602/10000 (96.02%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.2
# Two        - 95.5
# Three      - 95.7
# Four       - 97.0
# Five       - 96.7
# Six        - 97.8
# Seven      - 94.4
# Eight      - 89.3
# Nine       - 95.6
#
# Backdoor ASR 0.19
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.322253
#
# Average test loss: 0.1340, Test accuracy: 9610/10000 (96.10%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 96.4
# Three      - 96.1
# Four       - 96.8
# Five       - 96.3
# Six        - 98.4
# Seven      - 93.7
# Eight      - 89.3
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.309466
#
# Average test loss: 0.1210, Test accuracy: 9637/10000 (96.37%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.0
# Two        - 96.5
# Three      - 96.0
# Four       - 96.6
# Five       - 97.2
# Six        - 98.1
# Seven      - 94.9
# Eight      - 90.3
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.301549
#
# Average test loss: 0.1209, Test accuracy: 9643/10000 (96.43%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.0
# Two        - 96.4
# Three      - 97.4
# Four       - 96.8
# Five       - 96.9
# Six        - 98.0
# Seven      - 94.8
# Eight      - 89.6
# Nine       - 96.3
#
# Backdoor ASR 0.1
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.289269
#
# Average test loss: 0.1161, Test accuracy: 9660/10000 (96.60%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.2
# Two        - 97.3
# Three      - 96.5
# Four       - 97.1
# Five       - 97.5
# Six        - 98.0
# Seven      - 95.3
# Eight      - 90.2
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.276829
#
# Average test loss: 0.1067, Test accuracy: 9681/10000 (96.81%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 96.8
# Three      - 97.3
# Four       - 96.5
# Five       - 97.5
# Six        - 98.4
# Seven      - 95.7
# Eight      - 91.4
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.283252
#
# Average test loss: 0.1037, Test accuracy: 9696/10000 (96.96%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.2
# Two        - 97.2
# Three      - 97.7
# Four       - 96.6
# Five       - 97.2
# Six        - 98.7
# Seven      - 95.9
# Eight      - 91.7
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.270286
#
# Average test loss: 0.1059, Test accuracy: 9675/10000 (96.75%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.4
# Two        - 97.0
# Three      - 97.0
# Four       - 96.7
# Five       - 97.5
# Six        - 98.6
# Seven      - 95.5
# Eight      - 90.3
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.267455
#
# Average test loss: 0.1026, Test accuracy: 9696/10000 (96.96%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.5
# Two        - 97.1
# Three      - 97.5
# Four       - 97.0
# Five       - 97.5
# Six        - 98.4
# Seven      - 95.9
# Eight      - 91.4
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.265003
#
# Average test loss: 0.0977, Test accuracy: 9708/10000 (97.08%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.5
# Two        - 97.4
# Three      - 97.4
# Four       - 96.8
# Five       - 98.0
# Six        - 98.4
# Seven      - 96.0
# Eight      - 91.9
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.258379
#
# Average test loss: 0.0978, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.4
# Two        - 97.2
# Three      - 97.3
# Four       - 96.4
# Five       - 98.2
# Six        - 98.4
# Seven      - 95.6
# Eight      - 92.3
# Nine       - 97.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.255558
#
# Average test loss: 0.0936, Test accuracy: 9721/10000 (97.21%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.5
# Two        - 97.2
# Three      - 97.8
# Four       - 97.3
# Five       - 98.0
# Six        - 98.4
# Seven      - 96.3
# Eight      - 92.1
# Nine       - 96.7
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.250883
#
# Average test loss: 0.0871, Test accuracy: 9725/10000 (97.25%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.3
# Two        - 97.1
# Three      - 97.4
# Four       - 97.1
# Five       - 98.0
# Six        - 98.5
# Seven      - 96.3
# Eight      - 93.2
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.242174
#
# Average test loss: 0.0900, Test accuracy: 9719/10000 (97.19%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.4
# Two        - 97.3
# Three      - 97.8
# Four       - 96.4
# Five       - 97.3
# Six        - 98.9
# Seven      - 96.2
# Eight      - 92.8
# Nine       - 97.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.242180
#
# Average test loss: 0.0912, Test accuracy: 9716/10000 (97.16%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 97.3
# Three      - 97.4
# Four       - 96.5
# Five       - 98.2
# Six        - 98.6
# Seven      - 96.4
# Eight      - 91.8
# Nine       - 97.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.241449
#
# Average test loss: 0.0883, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 97.6
# Three      - 97.2
# Four       - 97.4
# Five       - 97.8
# Six        - 98.5
# Seven      - 96.8
# Eight      - 92.0
# Nine       - 97.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.236452
#
# Average test loss: 0.0873, Test accuracy: 9723/10000 (97.23%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.4
# Two        - 97.6
# Three      - 97.3
# Four       - 97.3
# Five       - 97.4
# Six        - 98.9
# Seven      - 96.2
# Eight      - 92.4
# Nine       - 97.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.238840
#
# Average test loss: 0.0829, Test accuracy: 9749/10000 (97.49%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.2
# Two        - 98.1
# Three      - 97.8
# Four       - 97.0
# Five       - 97.6
# Six        - 99.0
# Seven      - 97.0
# Eight      - 92.5
# Nine       - 97.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.235517
#
# Average test loss: 0.0831, Test accuracy: 9746/10000 (97.46%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.0
# Three      - 97.7
# Four       - 98.0
# Five       - 97.4
# Six        - 98.6
# Seven      - 96.9
# Eight      - 92.4
# Nine       - 97.1
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0887, Test accuracy: 9725/10000 (97.25%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.3
# Two        - 97.4
# Three      - 97.5
# Four       - 96.9
# Five       - 98.1
# Six        - 98.6
# Seven      - 96.4
# Eight      - 92.4
# Nine       - 96.9
# Global accuracies:  [65.22, 81.39, 88.31, 91.4, 92.63, 93.63, 94.54, 94.7, 95.15, 95.48, 95.77, 96.02, 96.1, 96.37, 96.43, 96.6, 96.81, 96.96, 96.75, 96.96, 97.08, 97.09, 97.21, 97.25, 97.19, 97.16, 97.27, 97.23, 97.49, 97.46, 97.25]
# Class 2 accuracies:  [79.55, 86.53, 91.18, 91.38, 92.25, 93.7, 94.28, 94.57, 95.45, 95.25, 96.22, 95.54, 96.41, 96.51, 96.41, 97.29, 96.8, 97.19, 97.0, 97.09, 97.38, 97.19, 97.19, 97.09, 97.29, 97.29, 97.58, 97.58, 98.06, 97.97, 97.38]
# Test loss: [1.8217, 0.6624, 0.4338, 0.3209, 0.2687, 0.2261, 0.1946, 0.1829, 0.1689, 0.1583, 0.1453, 0.1356, 0.134, 0.121, 0.1209, 0.1161, 0.1067, 0.1037, 0.1059, 0.1026, 0.0977, 0.0978, 0.0936, 0.0871, 0.09, 0.0912, 0.0883, 0.0873, 0.0829, 0.0831, 0.0887]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.011337510744730632
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: foolsgold
# Attack Type: backdoor
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.893724
#
# Average test loss: 1.8198, Test accuracy: 6577/10000 (65.77%)
#
# Class      - Accuracy
# Zero       - 60.0
# One        - 98.0
# Two        - 79.4
# Three      - 92.8
# Four       - 84.6
# Five       - 10.3
# Six        - 81.9
# Seven      - 83.9
# Eight      - 2.5
# Nine       - 52.1
#
# Backdoor ASR 0.29
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.183901
#
# Average test loss: 0.6891, Test accuracy: 8126/10000 (81.26%)
#
# Class      - Accuracy
# Zero       - 94.6
# One        - 98.8
# Two        - 86.1
# Three      - 88.3
# Four       - 89.0
# Five       - 45.3
# Six        - 94.3
# Seven      - 87.5
# Eight      - 36.2
# Nine       - 85.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.768382
#
# Average test loss: 0.4109, Test accuracy: 9032/10000 (90.32%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.6
# Two        - 92.2
# Three      - 90.6
# Four       - 93.3
# Five       - 83.2
# Six        - 96.9
# Seven      - 89.5
# Eight      - 68.7
# Nine       - 89.9
#
# Backdoor ASR 0.19
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.620521
#
# Average test loss: 0.3051, Test accuracy: 9219/10000 (92.19%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.9
# Two        - 91.8
# Three      - 90.7
# Four       - 95.9
# Five       - 88.1
# Six        - 96.1
# Seven      - 89.9
# Eight      - 79.9
# Nine       - 91.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.535891
#
# Average test loss: 0.2545, Test accuracy: 9320/10000 (93.20%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.9
# Two        - 93.4
# Three      - 92.0
# Four       - 95.6
# Five       - 91.9
# Six        - 97.4
# Seven      - 88.7
# Eight      - 82.4
# Nine       - 92.8
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.498254
#
# Average test loss: 0.2220, Test accuracy: 9389/10000 (93.89%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.9
# Two        - 94.2
# Three      - 92.2
# Four       - 96.1
# Five       - 93.9
# Six        - 97.3
# Seven      - 88.2
# Eight      - 85.4
# Nine       - 94.2
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.453033
#
# Average test loss: 0.1887, Test accuracy: 9473/10000 (94.73%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.9
# Two        - 94.3
# Three      - 93.8
# Four       - 96.7
# Five       - 93.8
# Six        - 97.9
# Seven      - 90.4
# Eight      - 89.1
# Nine       - 94.1
#
# Backdoor ASR 0.19
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.428701
#
# Average test loss: 0.1777, Test accuracy: 9520/10000 (95.20%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 95.3
# Three      - 93.8
# Four       - 96.3
# Five       - 95.4
# Six        - 97.5
# Seven      - 91.2
# Eight      - 89.8
# Nine       - 94.7
#
# Backdoor ASR 0.19
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.404357
#
# Average test loss: 0.1673, Test accuracy: 9546/10000 (95.46%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.1
# Three      - 93.7
# Four       - 96.5
# Five       - 96.6
# Six        - 97.7
# Seven      - 91.6
# Eight      - 90.5
# Nine       - 95.2
#
# Backdoor ASR 0.19
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.386923
#
# Average test loss: 0.1546, Test accuracy: 9568/10000 (95.68%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.0
# Three      - 95.2
# Four       - 96.6
# Five       - 97.0
# Six        - 97.8
# Seven      - 91.7
# Eight      - 89.4
# Nine       - 95.2
#
# Backdoor ASR 0.1
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.368800
#
# Average test loss: 0.1412, Test accuracy: 9613/10000 (96.13%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 96.3
# Three      - 95.2
# Four       - 96.7
# Five       - 96.9
# Six        - 98.0
# Seven      - 92.9
# Eight      - 91.7
# Nine       - 95.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.359510
#
# Average test loss: 0.1360, Test accuracy: 9618/10000 (96.18%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 96.9
# Three      - 95.1
# Four       - 96.1
# Five       - 97.9
# Six        - 97.7
# Seven      - 92.7
# Eight      - 91.4
# Nine       - 96.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.343422
#
# Average test loss: 0.1240, Test accuracy: 9647/10000 (96.47%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 96.8
# Three      - 95.8
# Four       - 96.8
# Five       - 97.5
# Six        - 97.8
# Seven      - 94.0
# Eight      - 91.9
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.332598
#
# Average test loss: 0.1173, Test accuracy: 9666/10000 (96.66%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.3
# Two        - 97.1
# Three      - 96.0
# Four       - 96.3
# Five       - 97.8
# Six        - 97.7
# Seven      - 94.1
# Eight      - 93.4
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.328320
#
# Average test loss: 0.1133, Test accuracy: 9671/10000 (96.71%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.7
# Three      - 95.9
# Four       - 96.7
# Five       - 97.9
# Six        - 98.1
# Seven      - 93.9
# Eight      - 94.0
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.314489
#
# Average test loss: 0.1057, Test accuracy: 9692/10000 (96.92%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.1
# Two        - 97.6
# Three      - 96.1
# Four       - 96.4
# Five       - 98.2
# Six        - 97.8
# Seven      - 94.3
# Eight      - 94.6
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.314581
#
# Average test loss: 0.1102, Test accuracy: 9667/10000 (96.67%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 97.3
# Three      - 96.8
# Four       - 96.2
# Five       - 98.1
# Six        - 97.7
# Seven      - 93.6
# Eight      - 92.7
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.303063
#
# Average test loss: 0.1003, Test accuracy: 9698/10000 (96.98%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 97.8
# Three      - 96.6
# Four       - 97.0
# Five       - 98.1
# Six        - 97.7
# Seven      - 94.6
# Eight      - 93.3
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.296979
#
# Average test loss: 0.0954, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.0
# Two        - 97.7
# Three      - 97.1
# Four       - 96.2
# Five       - 98.4
# Six        - 97.8
# Seven      - 94.8
# Eight      - 94.0
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.290021
#
# Average test loss: 0.0960, Test accuracy: 9722/10000 (97.22%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.4
# Two        - 97.8
# Three      - 96.6
# Four       - 96.8
# Five       - 98.1
# Six        - 98.0
# Seven      - 95.7
# Eight      - 93.8
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
#
# Average of peers' local losses: 0.293510
#
# Average test loss: 0.0928, Test accuracy: 9728/10000 (97.28%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.4
# Two        - 97.8
# Three      - 96.8
# Four       - 96.7
# Five       - 98.4
# Six        - 98.0
# Seven      - 95.4
# Eight      - 94.3
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.287679
#
# Average test loss: 0.0901, Test accuracy: 9720/10000 (97.20%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.6
# Three      - 97.5
# Four       - 96.5
# Five       - 98.3
# Six        - 97.9
# Seven      - 95.0
# Eight      - 94.1
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.282825
#
# Average test loss: 0.0859, Test accuracy: 9736/10000 (97.36%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.8
# Three      - 97.0
# Four       - 97.3
# Five       - 98.3
# Six        - 98.2
# Seven      - 95.5
# Eight      - 94.9
# Nine       - 96.2
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.275003
#
# Average test loss: 0.0839, Test accuracy: 9741/10000 (97.41%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.7
# Three      - 97.1
# Four       - 96.6
# Five       - 98.4
# Six        - 97.9
# Seven      - 95.7
# Eight      - 95.4
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.271236
#
# Average test loss: 0.0843, Test accuracy: 9744/10000 (97.44%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.5
# Two        - 97.5
# Three      - 97.7
# Four       - 96.9
# Five       - 98.3
# Six        - 98.0
# Seven      - 96.2
# Eight      - 93.8
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.269599
#
# Average test loss: 0.0807, Test accuracy: 9750/10000 (97.50%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 98.0
# Three      - 97.6
# Four       - 96.9
# Five       - 98.3
# Six        - 98.1
# Seven      - 96.2
# Eight      - 94.6
# Nine       - 97.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.269959
#
# Average test loss: 0.0816, Test accuracy: 9739/10000 (97.39%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.3
# Three      - 97.4
# Four       - 97.0
# Five       - 98.3
# Six        - 98.1
# Seven      - 96.2
# Eight      - 93.9
# Nine       - 97.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.265260
#
# Average test loss: 0.0778, Test accuracy: 9755/10000 (97.55%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.6
# Three      - 97.3
# Four       - 97.4
# Five       - 98.1
# Six        - 98.5
# Seven      - 96.3
# Eight      - 94.9
# Nine       - 97.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.265252
#
# Average test loss: 0.0788, Test accuracy: 9755/10000 (97.55%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.6
# Two        - 97.9
# Three      - 97.6
# Four       - 97.7
# Five       - 98.2
# Six        - 98.1
# Seven      - 96.4
# Eight      - 93.8
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.260338
#
# Average test loss: 0.0767, Test accuracy: 9763/10000 (97.63%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.6
# Two        - 98.1
# Three      - 97.6
# Four       - 97.1
# Five       - 98.3
# Six        - 98.3
# Seven      - 96.1
# Eight      - 94.7
# Nine       - 97.1
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0820, Test accuracy: 9745/10000 (97.45%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.5
# Two        - 97.7
# Three      - 97.5
# Four       - 97.1
# Five       - 98.3
# Six        - 98.2
# Seven      - 95.8
# Eight      - 94.3
# Nine       - 96.9
# Global accuracies:  [65.77, 81.26, 90.32, 92.19, 93.2, 93.89, 94.73, 95.2, 95.46, 95.68, 96.13, 96.18, 96.47, 96.66, 96.71, 96.92, 96.67, 96.98, 97.09, 97.22, 97.28, 97.2, 97.36, 97.41, 97.44, 97.5, 97.39, 97.55, 97.55, 97.63, 97.45]
# Class 2 accuracies:  [79.36, 86.14, 92.15, 91.76, 93.41, 94.19, 94.28, 95.35, 95.06, 96.03, 96.32, 96.9, 96.8, 97.09, 96.71, 97.58, 97.29, 97.77, 97.67, 97.77, 97.77, 97.58, 97.77, 97.67, 97.48, 97.97, 97.29, 97.58, 97.87, 98.06, 97.67]
# Test loss: [1.8198, 0.6891, 0.4109, 0.3051, 0.2545, 0.222, 0.1887, 0.1777, 0.1673, 0.1546, 0.1412, 0.136, 0.124, 0.1173, 0.1133, 0.1057, 0.1102, 0.1003, 0.0954, 0.096, 0.0928, 0.0901, 0.0859, 0.0839, 0.0843, 0.0807, 0.0816, 0.0778, 0.0788, 0.0767, 0.082]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.01169896920522054
#
# --> End of Experiment.

# %%
RULE = 'fl_defender'
ATTACK_TYPE='backdoor'
MALICIOUS_BEHAVIOR_RATE = 1
for atr in [0.0, 0.1, 0.2]:
    run_exp(dataset_name = DATASET_NAME, model_name = MODEL_NAME, dd_type = DD_TYPE, num_peers = NUM_PEERS, 
            frac_peers = FRAC_PEERS, seed = SEED, test_batch_size = TEST_BATCH_SIZE,
                criterion = CRITERION, global_rounds = GLOBAL_ROUNDS, local_epochs = LOCAL_EPOCHS, local_bs = LOCAL_BS, 
                 local_lr = LOCAL_LR, local_momentum = LOCAL_MOMENTUM, labels_dict = LABELS_DICT, device = DEVICE,
                attackers_ratio = atr, attack_type=ATTACK_TYPE, 
                 malicious_behavior_rate = MALICIOUS_BEHAVIOR_RATE, rule = RULE,
                source_class = SOURCE_CLASS, target_class = TARGET_CLASS,
               class_per_peer = CLASS_PER_PEER, samples_per_class = SAMPLES_PER_CLASS, 
               rate_unbalance = RATE_UNBALANCE, alpha = ALPHA, resume = False)
# Out:
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: fl_defender
# Attack Type: backdoor
# Attackers Ratio: 0.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.885287
# -> Update score history
# Aggregation took 0.027
#
# Average test loss: 1.6730, Test accuracy: 6317/10000 (63.17%)
#
# Class      - Accuracy
# Zero       - 90.3
# One        - 98.8
# Two        - 58.3
# Three      - 64.1
# Four       - 88.0
# Five       - 3.5
# Six        - 86.1
# Seven      - 86.1
# Eight      - 0.1
# Nine       - 45.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.107668
# -> Update score history
# Aggregation took 0.011
#
# Average test loss: 0.7538, Test accuracy: 7575/10000 (75.75%)
#
# Class      - Accuracy
# Zero       - 97.9
# One        - 98.9
# Two        - 73.1
# Three      - 83.9
# Four       - 88.1
# Five       - 21.6
# Six        - 96.6
# Seven      - 88.5
# Eight      - 9.8
# Nine       - 89.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.738858
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.3723, Test accuracy: 9087/10000 (90.87%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.4
# Two        - 93.6
# Three      - 84.6
# Four       - 95.8
# Five       - 85.4
# Six        - 95.3
# Seven      - 90.4
# Eight      - 80.1
# Nine       - 85.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.567327
# -> Update score history
# Aggregation took 0.0085
#
# Average test loss: 0.3238, Test accuracy: 9091/10000 (90.91%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.1
# Two        - 90.2
# Three      - 89.7
# Four       - 94.9
# Five       - 86.3
# Six        - 97.3
# Seven      - 94.0
# Eight      - 65.1
# Nine       - 92.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.496551
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.2323, Test accuracy: 9393/10000 (93.93%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.8
# Two        - 93.9
# Three      - 89.9
# Four       - 96.2
# Five       - 94.4
# Six        - 96.8
# Seven      - 93.3
# Eight      - 85.4
# Nine       - 91.9
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.434886
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.2166, Test accuracy: 9413/10000 (94.13%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 94.8
# Three      - 89.6
# Four       - 96.6
# Five       - 94.4
# Six        - 97.5
# Seven      - 95.4
# Eight      - 83.6
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.407026
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1938, Test accuracy: 9476/10000 (94.76%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 93.6
# Three      - 92.5
# Four       - 96.5
# Five       - 93.7
# Six        - 97.9
# Seven      - 96.0
# Eight      - 85.7
# Nine       - 93.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.378811
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1705, Test accuracy: 9513/10000 (95.13%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.7
# Two        - 95.6
# Three      - 90.5
# Four       - 96.0
# Five       - 96.1
# Six        - 97.9
# Seven      - 93.7
# Eight      - 90.1
# Nine       - 94.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.352949
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.1592, Test accuracy: 9559/10000 (95.59%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.3
# Three      - 92.5
# Four       - 96.3
# Five       - 94.7
# Six        - 98.4
# Seven      - 96.2
# Eight      - 90.2
# Nine       - 94.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.344733
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1559, Test accuracy: 9539/10000 (95.39%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 96.0
# Three      - 93.8
# Four       - 96.0
# Five       - 94.7
# Six        - 98.3
# Seven      - 93.1
# Eight      - 88.2
# Nine       - 95.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.325647
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.1433, Test accuracy: 9586/10000 (95.86%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 96.4
# Three      - 94.9
# Four       - 97.3
# Five       - 95.7
# Six        - 98.1
# Seven      - 95.5
# Eight      - 87.8
# Nine       - 94.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.311526
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1365, Test accuracy: 9608/10000 (96.08%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.2
# Two        - 95.1
# Three      - 95.1
# Four       - 97.1
# Five       - 96.6
# Six        - 98.4
# Seven      - 96.3
# Eight      - 88.8
# Nine       - 95.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.294663
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1256, Test accuracy: 9646/10000 (96.46%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 96.1
# Three      - 94.4
# Four       - 97.5
# Five       - 97.6
# Six        - 98.1
# Seven      - 96.6
# Eight      - 91.3
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.285056
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.1295, Test accuracy: 9640/10000 (96.40%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.4
# Two        - 96.1
# Three      - 94.9
# Four       - 97.4
# Five       - 96.7
# Six        - 98.4
# Seven      - 95.7
# Eight      - 90.5
# Nine       - 95.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.279930
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1138, Test accuracy: 9658/10000 (96.58%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.9
# Two        - 97.4
# Three      - 95.4
# Four       - 97.3
# Five       - 98.2
# Six        - 98.2
# Seven      - 93.8
# Eight      - 92.9
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.268300
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1074, Test accuracy: 9677/10000 (96.77%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 97.4
# Three      - 95.5
# Four       - 97.7
# Five       - 98.2
# Six        - 97.8
# Seven      - 94.7
# Eight      - 93.0
# Nine       - 95.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.260420
# -> Update score history
# Aggregation took 0.0089
#
# Average test loss: 0.1049, Test accuracy: 9687/10000 (96.87%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 98.4
# Three      - 95.2
# Four       - 98.2
# Five       - 98.7
# Six        - 97.5
# Seven      - 93.5
# Eight      - 94.7
# Nine       - 94.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.256226
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0998, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 97.7
# Three      - 95.8
# Four       - 97.6
# Five       - 98.0
# Six        - 98.5
# Seven      - 95.4
# Eight      - 94.0
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.250988
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0994, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 97.7
# Three      - 95.1
# Four       - 97.3
# Five       - 98.2
# Six        - 98.4
# Seven      - 95.8
# Eight      - 93.8
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.240886
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0993, Test accuracy: 9703/10000 (97.03%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.9
# Two        - 96.7
# Three      - 96.2
# Four       - 97.3
# Five       - 97.2
# Six        - 98.6
# Seven      - 96.8
# Eight      - 93.4
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
# Average of peers' local losses: 0.240303
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0953, Test accuracy: 9720/10000 (97.20%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 97.2
# Three      - 96.5
# Four       - 97.3
# Five       - 97.9
# Six        - 98.7
# Seven      - 95.8
# Eight      - 94.3
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.238688
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.0872, Test accuracy: 9745/10000 (97.45%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 97.2
# Three      - 96.2
# Four       - 97.5
# Five       - 98.0
# Six        - 98.2
# Seven      - 96.7
# Eight      - 96.4
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.236262
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0958, Test accuracy: 9711/10000 (97.11%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 99.1
# Two        - 97.6
# Three      - 96.0
# Four       - 97.8
# Five       - 97.6
# Six        - 98.7
# Seven      - 95.7
# Eight      - 93.5
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.226239
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0891, Test accuracy: 9736/10000 (97.36%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 97.8
# Three      - 95.6
# Four       - 98.2
# Five       - 97.8
# Six        - 98.6
# Seven      - 96.3
# Eight      - 95.4
# Nine       - 95.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.224191
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0838, Test accuracy: 9748/10000 (97.48%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 98.0
# Three      - 96.8
# Four       - 97.9
# Five       - 98.0
# Six        - 98.7
# Seven      - 96.0
# Eight      - 95.3
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.217026
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0830, Test accuracy: 9743/10000 (97.43%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.1
# Two        - 98.0
# Three      - 96.1
# Four       - 97.0
# Five       - 98.0
# Six        - 98.7
# Seven      - 96.3
# Eight      - 95.7
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.218629
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0797, Test accuracy: 9759/10000 (97.59%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 97.5
# Three      - 96.2
# Four       - 97.7
# Five       - 98.2
# Six        - 98.2
# Seven      - 97.2
# Eight      - 95.9
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.211559
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.0799, Test accuracy: 9761/10000 (97.61%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.5
# Two        - 97.8
# Three      - 96.9
# Four       - 97.8
# Five       - 98.2
# Six        - 98.6
# Seven      - 96.6
# Eight      - 95.3
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.211983
# -> Update score history
# Aggregation took 0.0082
#
# Average test loss: 0.0766, Test accuracy: 9774/10000 (97.74%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 98.3
# Three      - 96.6
# Four       - 98.6
# Five       - 98.0
# Six        - 98.5
# Seven      - 96.6
# Eight      - 96.4
# Nine       - 96.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.208772
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.0765, Test accuracy: 9769/10000 (97.69%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.4
# Two        - 98.4
# Three      - 95.7
# Four       - 98.7
# Five       - 98.7
# Six        - 97.7
# Seven      - 96.0
# Eight      - 96.7
# Nine       - 96.3
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0826, Test accuracy: 9750/10000 (97.50%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 97.9
# Three      - 96.4
# Four       - 97.9
# Five       - 98.2
# Six        - 98.6
# Seven      - 96.3
# Eight      - 95.5
# Nine       - 96.3
# Global accuracies:  [63.17, 75.75, 90.87, 90.91, 93.93, 94.13, 94.76, 95.13, 95.59, 95.39, 95.86, 96.08, 96.46, 96.4, 96.58, 96.77, 96.87, 97.0, 97.0, 97.03, 97.2, 97.45, 97.11, 97.36, 97.48, 97.43, 97.59, 97.61, 97.74, 97.69, 97.5]
# Class 2 accuracies:  [58.33, 73.06, 93.6, 90.21, 93.9, 94.77, 93.6, 95.64, 95.35, 96.03, 96.41, 95.06, 96.12, 96.12, 97.38, 97.38, 98.35, 97.67, 97.67, 96.71, 97.19, 97.19, 97.58, 97.77, 97.97, 97.97, 97.48, 97.77, 98.26, 98.35, 97.87]
# Test loss: [1.673, 0.7538, 0.3723, 0.3238, 0.2323, 0.2166, 0.1938, 0.1705, 0.1592, 0.1559, 0.1433, 0.1365, 0.1256, 0.1295, 0.1138, 0.1074, 0.1049, 0.0998, 0.0994, 0.0993, 0.0953, 0.0872, 0.0958, 0.0891, 0.0838, 0.083, 0.0797, 0.0799, 0.0766, 0.0765, 0.0826]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.009589727719624836
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: fl_defender
# Attack Type: backdoor
# Attackers Ratio: 10.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.892177
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 1.6991, Test accuracy: 6200/10000 (62.00%)
#
# Class      - Accuracy
# Zero       - 90.0
# One        - 98.1
# Two        - 55.5
# Three      - 57.1
# Four       - 91.2
# Five       - 11.5
# Six        - 85.6
# Seven      - 88.4
# Eight      - 0.0
# Nine       - 32.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.130671
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.5469, Test accuracy: 8688/10000 (86.88%)
#
# Class      - Accuracy
# Zero       - 95.1
# One        - 98.1
# Two        - 87.7
# Three      - 78.9
# Four       - 93.6
# Five       - 77.6
# Six        - 96.3
# Seven      - 91.3
# Eight      - 73.1
# Nine       - 74.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.703615
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.3321, Test accuracy: 9134/10000 (91.34%)
#
# Class      - Accuracy
# Zero       - 97.2
# One        - 98.7
# Two        - 94.2
# Three      - 86.9
# Four       - 96.6
# Five       - 90.2
# Six        - 96.7
# Seven      - 90.8
# Eight      - 81.8
# Nine       - 79.4
#
# Backdoor ASR 0.1
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.559715
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.2618, Test accuracy: 9312/10000 (93.12%)
#
# Class      - Accuracy
# Zero       - 98.0
# One        - 98.7
# Two        - 93.2
# Three      - 91.1
# Four       - 96.6
# Five       - 91.8
# Six        - 97.1
# Seven      - 93.3
# Eight      - 83.7
# Nine       - 87.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.489107
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.2139, Test accuracy: 9410/10000 (94.10%)
#
# Class      - Accuracy
# Zero       - 98.1
# One        - 98.9
# Two        - 92.7
# Three      - 91.9
# Four       - 96.8
# Five       - 93.7
# Six        - 97.8
# Seven      - 93.7
# Eight      - 87.8
# Nine       - 89.2
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.437067
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1953, Test accuracy: 9450/10000 (94.50%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.7
# Two        - 94.4
# Three      - 92.0
# Four       - 96.4
# Five       - 96.1
# Six        - 97.5
# Seven      - 92.6
# Eight      - 86.2
# Nine       - 92.5
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.411654
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1668, Test accuracy: 9530/10000 (95.30%)
#
# Class      - Accuracy
# Zero       - 98.5
# One        - 98.8
# Two        - 96.6
# Three      - 93.0
# Four       - 96.8
# Five       - 95.1
# Six        - 97.6
# Seven      - 93.9
# Eight      - 91.0
# Nine       - 91.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.383018
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.1590, Test accuracy: 9543/10000 (95.43%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.8
# Three      - 91.7
# Four       - 96.7
# Five       - 95.6
# Six        - 97.9
# Seven      - 95.6
# Eight      - 90.7
# Nine       - 92.5
#
# Backdoor ASR 0.1
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.364830
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.1425, Test accuracy: 9592/10000 (95.92%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 98.9
# Two        - 96.9
# Three      - 95.0
# Four       - 97.3
# Five       - 96.9
# Six        - 97.9
# Seven      - 94.6
# Eight      - 90.6
# Nine       - 92.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.341528
# -> Update score history
# Aggregation took 0.0095
#
# Average test loss: 0.1362, Test accuracy: 9597/10000 (95.97%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 95.6
# Three      - 93.7
# Four       - 97.3
# Five       - 97.5
# Six        - 97.7
# Seven      - 95.1
# Eight      - 91.5
# Nine       - 93.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.331016
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1317, Test accuracy: 9615/10000 (96.15%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.3
# Two        - 93.8
# Three      - 94.9
# Four       - 97.4
# Five       - 97.0
# Six        - 97.6
# Seven      - 96.6
# Eight      - 93.2
# Nine       - 93.0
#
# Backdoor ASR 0.1
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.316843
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1170, Test accuracy: 9660/10000 (96.60%)
#
# Class      - Accuracy
# Zero       - 98.4
# One        - 99.3
# Two        - 96.5
# Three      - 95.2
# Four       - 97.5
# Five       - 97.3
# Six        - 97.6
# Seven      - 94.7
# Eight      - 95.2
# Nine       - 94.2
#
# Backdoor ASR 0.19
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.312768
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.1180, Test accuracy: 9653/10000 (96.53%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 96.9
# Three      - 95.1
# Four       - 97.5
# Five       - 97.5
# Six        - 97.8
# Seven      - 95.7
# Eight      - 91.9
# Nine       - 94.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.301089
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1107, Test accuracy: 9674/10000 (96.74%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.3
# Two        - 97.7
# Three      - 93.9
# Four       - 97.6
# Five       - 98.1
# Six        - 97.6
# Seven      - 95.7
# Eight      - 94.5
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.294719
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1097, Test accuracy: 9697/10000 (96.97%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.4
# Three      - 95.6
# Four       - 97.6
# Five       - 97.4
# Six        - 98.3
# Seven      - 96.5
# Eight      - 93.0
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.283785
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1063, Test accuracy: 9687/10000 (96.87%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.1
# Two        - 97.3
# Three      - 95.6
# Four       - 97.4
# Five       - 98.0
# Six        - 97.9
# Seven      - 96.5
# Eight      - 92.4
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.271816
# -> Update score history
# Aggregation took 0.0101
#
# Average test loss: 0.1045, Test accuracy: 9696/10000 (96.96%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.3
# Two        - 96.5
# Three      - 95.6
# Four       - 97.7
# Five       - 97.9
# Six        - 98.4
# Seven      - 97.0
# Eight      - 92.8
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.277590
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0992, Test accuracy: 9722/10000 (97.22%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.4
# Two        - 97.5
# Three      - 96.2
# Four       - 98.2
# Five       - 97.9
# Six        - 98.5
# Seven      - 96.3
# Eight      - 93.8
# Nine       - 95.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.262377
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1029, Test accuracy: 9709/10000 (97.09%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 97.2
# Three      - 96.5
# Four       - 98.2
# Five       - 97.9
# Six        - 98.5
# Seven      - 96.4
# Eight      - 92.0
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.262888
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.0974, Test accuracy: 9711/10000 (97.11%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.1
# Two        - 98.0
# Three      - 96.2
# Four       - 97.3
# Five       - 98.1
# Six        - 98.4
# Seven      - 96.3
# Eight      - 92.9
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
# Average of peers' local losses: 0.260218
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.0918, Test accuracy: 9733/10000 (97.33%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.4
# Two        - 97.8
# Three      - 95.7
# Four       - 97.1
# Five       - 98.4
# Six        - 98.4
# Seven      - 96.3
# Eight      - 95.2
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.254111
# -> Update score history
# Aggregation took 0.0089
#
# Average test loss: 0.0889, Test accuracy: 9737/10000 (97.37%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.4
# Three      - 96.4
# Four       - 97.7
# Five       - 98.5
# Six        - 98.4
# Seven      - 96.7
# Eight      - 93.9
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.250171
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.0846, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.8
# Three      - 96.9
# Four       - 97.6
# Five       - 98.0
# Six        - 98.5
# Seven      - 97.0
# Eight      - 95.2
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.245643
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0823, Test accuracy: 9762/10000 (97.62%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 97.5
# Three      - 96.5
# Four       - 98.1
# Five       - 98.8
# Six        - 98.4
# Seven      - 97.1
# Eight      - 95.3
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.239103
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.0840, Test accuracy: 9754/10000 (97.54%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.4
# Two        - 97.3
# Three      - 96.8
# Four       - 97.0
# Five       - 98.3
# Six        - 98.6
# Seven      - 97.3
# Eight      - 94.8
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.236823
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.0851, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 96.9
# Three      - 96.9
# Four       - 97.5
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.6
# Eight      - 93.9
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.236260
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0828, Test accuracy: 9760/10000 (97.60%)
#
# Class      - Accuracy
# Zero       - 99.3
# One        - 99.3
# Two        - 97.3
# Three      - 95.9
# Four       - 98.3
# Five       - 98.3
# Six        - 98.5
# Seven      - 97.5
# Eight      - 95.2
# Nine       - 96.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.229346
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0793, Test accuracy: 9768/10000 (97.68%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.3
# Two        - 97.6
# Three      - 96.5
# Four       - 98.2
# Five       - 98.3
# Six        - 98.7
# Seven      - 97.5
# Eight      - 95.1
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.229385
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0746, Test accuracy: 9784/10000 (97.84%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.3
# Three      - 96.7
# Four       - 98.2
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.5
# Eight      - 95.6
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.224133
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0749, Test accuracy: 9783/10000 (97.83%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.3
# Two        - 98.4
# Three      - 96.8
# Four       - 98.2
# Five       - 98.7
# Six        - 98.7
# Seven      - 97.3
# Eight      - 95.6
# Nine       - 96.4
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0816, Test accuracy: 9760/10000 (97.60%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.7
# Three      - 96.5
# Four       - 97.9
# Five       - 98.4
# Six        - 98.6
# Seven      - 97.3
# Eight      - 94.9
# Nine       - 96.3
# Global accuracies:  [62.0, 86.88, 91.34, 93.12, 94.1, 94.5, 95.3, 95.43, 95.92, 95.97, 96.15, 96.6, 96.53, 96.74, 96.97, 96.87, 96.96, 97.22, 97.09, 97.11, 97.33, 97.37, 97.54, 97.62, 97.54, 97.53, 97.6, 97.68, 97.84, 97.83, 97.6]
# Class 2 accuracies:  [55.52, 87.69, 94.19, 93.22, 92.73, 94.38, 96.61, 95.83, 96.9, 95.64, 93.8, 96.51, 96.9, 97.67, 97.38, 97.29, 96.51, 97.48, 97.19, 97.97, 97.77, 97.38, 97.77, 97.48, 97.29, 96.9, 97.29, 97.58, 98.26, 98.35, 97.67]
# Test loss: [1.6991, 0.5469, 0.3321, 0.2618, 0.2139, 0.1953, 0.1668, 0.159, 0.1425, 0.1362, 0.1317, 0.117, 0.118, 0.1107, 0.1097, 0.1063, 0.1045, 0.0992, 0.1029, 0.0974, 0.0918, 0.0889, 0.0846, 0.0823, 0.084, 0.0851, 0.0828, 0.0793, 0.0746, 0.0749, 0.0816]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.008949851989746094
#
# --> End of Experiment.
#
# --> Starting experiment...
# --> Loading of MNIST dataset
# --> Dataset has been loaded!
# --> Creating CNNMNIST model.....
# --> Model has been created!
# --> Distributing training data among peers
# --> Training data have been distributed among peers
# --> Creating peers instances
# # of peers who have source class examples: 20
# Data set: MNIST
# Data distribution: MILD_NON_IID
# Aggregation rule: fl_defender
# Attack Type: backdoor
# Attackers Ratio: 20.0 %
# Malicious Behavior Rate: 100 %
#
# ===>Simulation started...
#
# ====>Global model training started...
#   0%|          | 0/30 [00:00<?, ?it/s]
#  | Global training round : 1/30 |
#
# Average of peers' local losses: 1.893831
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 1.6653, Test accuracy: 6569/10000 (65.69%)
#
# Class      - Accuracy
# Zero       - 95.0
# One        - 99.1
# Two        - 53.7
# Three      - 61.3
# Four       - 84.9
# Five       - 49.0
# Six        - 87.4
# Seven      - 88.3
# Eight      - 6.0
# Nine       - 26.4
#
# Backdoor ASR 0.78
#
#  | Global training round : 2/30 |
#
# Average of peers' local losses: 1.140991
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.7328, Test accuracy: 7793/10000 (77.93%)
#
# Class      - Accuracy
# Zero       - 97.8
# One        - 98.7
# Two        - 70.3
# Three      - 82.8
# Four       - 83.0
# Five       - 47.5
# Six        - 95.9
# Seven      - 89.3
# Eight      - 17.8
# Nine       - 89.6
#
# Backdoor ASR 0.1
#
#  | Global training round : 3/30 |
#
# Average of peers' local losses: 0.766211
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.3885, Test accuracy: 9042/10000 (90.42%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.7
# Two        - 91.8
# Three      - 87.4
# Four       - 92.9
# Five       - 91.3
# Six        - 96.5
# Seven      - 93.3
# Eight      - 66.0
# Nine       - 86.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 4/30 |
#
# Average of peers' local losses: 0.610339
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.2587, Test accuracy: 9308/10000 (93.08%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.7
# Two        - 93.8
# Three      - 86.2
# Four       - 96.6
# Five       - 94.2
# Six        - 96.2
# Seven      - 92.1
# Eight      - 86.2
# Nine       - 87.4
#
# Backdoor ASR 0.19
#
#  | Global training round : 5/30 |
#
# Average of peers' local losses: 0.524319
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.2130, Test accuracy: 9418/10000 (94.18%)
#
# Class      - Accuracy
# Zero       - 98.3
# One        - 98.6
# Two        - 95.1
# Three      - 90.9
# Four       - 96.4
# Five       - 96.0
# Six        - 96.9
# Seven      - 91.6
# Eight      - 88.4
# Nine       - 89.5
#
# Backdoor ASR 0.19
#
#  | Global training round : 6/30 |
#
# Average of peers' local losses: 0.494557
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1860, Test accuracy: 9484/10000 (94.84%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 98.9
# Two        - 94.4
# Three      - 93.0
# Four       - 96.3
# Five       - 96.4
# Six        - 97.3
# Seven      - 93.0
# Eight      - 88.5
# Nine       - 91.5
#
# Backdoor ASR 0.19
#
#  | Global training round : 7/30 |
#
# Average of peers' local losses: 0.451384
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1644, Test accuracy: 9534/10000 (95.34%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 98.9
# Two        - 94.4
# Three      - 93.7
# Four       - 96.2
# Five       - 96.6
# Six        - 97.8
# Seven      - 93.8
# Eight      - 89.9
# Nine       - 93.2
#
# Backdoor ASR 0.19
#
#  | Global training round : 8/30 |
#
# Average of peers' local losses: 0.432697
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1544, Test accuracy: 9552/10000 (95.52%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.2
# Two        - 95.5
# Three      - 94.0
# Four       - 96.5
# Five       - 97.0
# Six        - 97.7
# Seven      - 94.0
# Eight      - 89.2
# Nine       - 93.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 9/30 |
#
# Average of peers' local losses: 0.413230
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.1452, Test accuracy: 9588/10000 (95.88%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.0
# Two        - 95.4
# Three      - 93.9
# Four       - 96.4
# Five       - 97.5
# Six        - 97.4
# Seven      - 96.1
# Eight      - 90.1
# Nine       - 93.9
#
# Backdoor ASR 0.1
#
#  | Global training round : 10/30 |
#
# Average of peers' local losses: 0.405434
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1374, Test accuracy: 9604/10000 (96.04%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 98.9
# Two        - 95.6
# Three      - 95.4
# Four       - 95.9
# Five       - 97.3
# Six        - 98.0
# Seven      - 95.5
# Eight      - 89.4
# Nine       - 95.3
#
# Backdoor ASR 0.0
#
#  | Global training round : 11/30 |
#
# Average of peers' local losses: 0.386866
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1256, Test accuracy: 9647/10000 (96.47%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.4
# Two        - 96.4
# Three      - 94.4
# Four       - 97.0
# Five       - 97.4
# Six        - 98.0
# Seven      - 96.2
# Eight      - 92.4
# Nine       - 94.5
#
# Backdoor ASR 0.0
#
#  | Global training round : 12/30 |
#
# Average of peers' local losses: 0.384667
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1194, Test accuracy: 9652/10000 (96.52%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.2
# Two        - 97.1
# Three      - 94.4
# Four       - 96.6
# Five       - 98.1
# Six        - 97.6
# Seven      - 96.3
# Eight      - 92.4
# Nine       - 94.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 13/30 |
#
# Average of peers' local losses: 0.371513
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1120, Test accuracy: 9679/10000 (96.79%)
#
# Class      - Accuracy
# Zero       - 98.7
# One        - 99.2
# Two        - 97.3
# Three      - 96.1
# Four       - 96.9
# Five       - 97.9
# Six        - 98.1
# Seven      - 95.8
# Eight      - 92.5
# Nine       - 95.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 14/30 |
#
# Average of peers' local losses: 0.361527
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1086, Test accuracy: 9694/10000 (96.94%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.4
# Two        - 97.2
# Three      - 96.4
# Four       - 97.1
# Five       - 98.3
# Six        - 97.8
# Seven      - 96.2
# Eight      - 92.4
# Nine       - 95.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 15/30 |
#
# Average of peers' local losses: 0.359917
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.1071, Test accuracy: 9689/10000 (96.89%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 99.3
# Two        - 96.4
# Three      - 96.5
# Four       - 97.3
# Five       - 97.8
# Six        - 98.3
# Seven      - 96.2
# Eight      - 92.0
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 16/30 |
#
# Average of peers' local losses: 0.344648
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.1022, Test accuracy: 9700/10000 (97.00%)
#
# Class      - Accuracy
# Zero       - 98.8
# One        - 98.9
# Two        - 97.8
# Three      - 96.2
# Four       - 97.1
# Five       - 98.4
# Six        - 98.2
# Seven      - 96.0
# Eight      - 92.5
# Nine       - 95.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 17/30 |
#
# Average of peers' local losses: 0.354747
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.1021, Test accuracy: 9694/10000 (96.94%)
#
# Class      - Accuracy
# Zero       - 98.6
# One        - 99.2
# Two        - 97.1
# Three      - 97.0
# Four       - 97.3
# Five       - 98.5
# Six        - 98.0
# Seven      - 96.1
# Eight      - 91.4
# Nine       - 96.0
#
# Backdoor ASR 0.0
#
#  | Global training round : 18/30 |
#
# Average of peers' local losses: 0.337949
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0970, Test accuracy: 9694/10000 (96.94%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.0
# Two        - 97.6
# Three      - 96.4
# Four       - 97.6
# Five       - 98.4
# Six        - 97.8
# Seven      - 95.9
# Eight      - 91.5
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 19/30 |
#
# Average of peers' local losses: 0.334278
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0962, Test accuracy: 9711/10000 (97.11%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.3
# Three      - 97.1
# Four       - 96.9
# Five       - 98.2
# Six        - 98.2
# Seven      - 96.6
# Eight      - 92.0
# Nine       - 96.1
#
# Backdoor ASR 0.0
#
#  | Global training round : 20/30 |
#
# Average of peers' local losses: 0.326087
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.0987, Test accuracy: 9710/10000 (97.10%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.8
# Three      - 97.2
# Four       - 97.4
# Five       - 97.8
# Six        - 98.3
# Seven      - 96.4
# Eight      - 91.3
# Nine       - 96.2
#
# Backdoor ASR 0.0
#
#  | Global training round : 21/30 |
# Average of peers' local losses: 0.333315
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.0908, Test accuracy: 9727/10000 (97.27%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.5
# Two        - 97.8
# Three      - 96.8
# Four       - 97.7
# Five       - 98.7
# Six        - 97.7
# Seven      - 96.3
# Eight      - 92.7
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 22/30 |
#
# Average of peers' local losses: 0.328196
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0892, Test accuracy: 9733/10000 (97.33%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.4
# Three      - 97.6
# Four       - 97.1
# Five       - 98.7
# Six        - 98.3
# Seven      - 96.8
# Eight      - 92.4
# Nine       - 96.4
#
# Backdoor ASR 0.0
#
#  | Global training round : 23/30 |
#
# Average of peers' local losses: 0.324661
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0878, Test accuracy: 9746/10000 (97.46%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.6
# Two        - 97.7
# Three      - 97.6
# Four       - 98.2
# Five       - 98.3
# Six        - 98.2
# Seven      - 96.5
# Eight      - 92.7
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 24/30 |
#
# Average of peers' local losses: 0.320007
# -> Update score history
# Aggregation took 0.01
#
# Average test loss: 0.0837, Test accuracy: 9745/10000 (97.45%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.6
# Two        - 97.7
# Three      - 97.1
# Four       - 97.3
# Five       - 98.4
# Six        - 98.3
# Seven      - 96.9
# Eight      - 93.3
# Nine       - 96.8
#
# Backdoor ASR 0.0
#
#  | Global training round : 25/30 |
#
# Average of peers' local losses: 0.310481
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0878, Test accuracy: 9738/10000 (97.38%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 97.6
# Three      - 97.7
# Four       - 97.9
# Five       - 98.5
# Six        - 98.1
# Seven      - 97.2
# Eight      - 91.3
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 26/30 |
#
# Average of peers' local losses: 0.312795
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0815, Test accuracy: 9753/10000 (97.53%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.5
# Two        - 97.8
# Three      - 97.3
# Four       - 97.6
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.1
# Eight      - 93.2
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 27/30 |
#
# Average of peers' local losses: 0.318361
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0827, Test accuracy: 9751/10000 (97.51%)
#
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.6
# Two        - 97.5
# Three      - 97.4
# Four       - 98.2
# Five       - 98.5
# Six        - 98.2
# Seven      - 97.1
# Eight      - 92.7
# Nine       - 96.7
#
# Backdoor ASR 0.0
#
#  | Global training round : 28/30 |
#
# Average of peers' local losses: 0.305496
# -> Update score history
# Aggregation took 0.0105
#
# Average test loss: 0.0781, Test accuracy: 9775/10000 (97.75%)
#
# Class      - Accuracy
# Zero       - 98.9
# One        - 99.6
# Two        - 97.7
# Three      - 97.6
# Four       - 98.7
# Five       - 98.5
# Six        - 98.7
# Seven      - 97.3
# Eight      - 93.7
# Nine       - 96.6
#
# Backdoor ASR 0.0
#
#  | Global training round : 29/30 |
#
# Average of peers' local losses: 0.307297
# -> Update score history
# Aggregation took 0.008
#
# Average test loss: 0.0783, Test accuracy: 9767/10000 (97.67%)
#
# Class      - Accuracy
# Zero       - 99.1
# One        - 99.6
# Two        - 98.0
# Three      - 97.7
# Four       - 98.3
# Five       - 98.4
# Six        - 98.3
# Seven      - 97.1
# Eight      - 93.1
# Nine       - 96.9
#
# Backdoor ASR 0.0
#
#  | Global training round : 30/30 |
#
# Average of peers' local losses: 0.305323
# -> Update score history
# Aggregation took 0.009
#
# Average test loss: 0.0780, Test accuracy: 9756/10000 (97.56%)
#
# Class      - Accuracy
# Zero       - 99.2
# One        - 99.5
# Two        - 98.3
# Three      - 97.6
# Four       - 97.3
# Five       - 98.4
# Six        - 98.4
# Seven      - 96.7
# Eight      - 93.0
# Nine       - 97.0
#
# Backdoor ASR 0.0
# Last 10 updates results
#
# Average test loss: 0.0827, Test accuracy: 9748/10000 (97.48%)
#
# ***********************************************************************************
# Class      - Accuracy
# Zero       - 99.0
# One        - 99.5
# Two        - 97.6
# Three      - 97.6
# Four       - 97.6
# Five       - 98.5
# Six        - 98.3
# Seven      - 97.0
# Eight      - 92.7
# Nine       - 96.8
# Global accuracies:  [65.69, 77.93, 90.42, 93.08, 94.18, 94.84, 95.34, 95.52, 95.88, 96.04, 96.47, 96.52, 96.79, 96.94, 96.89, 97.0, 96.94, 96.94, 97.11, 97.1, 97.27, 97.33, 97.46, 97.45, 97.38, 97.53, 97.51, 97.75, 97.67, 97.56, 97.48]
# Class 2 accuracies:  [53.68, 70.35, 91.76, 93.8, 95.06, 94.38, 94.38, 95.54, 95.45, 95.64, 96.41, 97.09, 97.29, 97.19, 96.41, 97.77, 97.09, 97.58, 97.29, 97.77, 97.77, 97.38, 97.67, 97.67, 97.58, 97.77, 97.48, 97.67, 97.97, 98.26, 97.58]
# Test loss: [1.6653, 0.7328, 0.3885, 0.2587, 0.213, 0.186, 0.1644, 0.1544, 0.1452, 0.1374, 0.1256, 0.1194, 0.112, 0.1086, 0.1071, 0.1022, 0.1021, 0.097, 0.0962, 0.0987, 0.0908, 0.0892, 0.0878, 0.0837, 0.0878, 0.0815, 0.0827, 0.0781, 0.0783, 0.078, 0.0827]
# Label-flipping attack succes rate: 0.0
# Backdoor attack succes rate: 0.0
# Average CPU aggregation runtime: 0.009053993225097656
#
# --> End of Experiment.
